# %% [markdown]
# <h2 style="text-align: center;"><b>Нейронная сеть из одного нейрона</b></h3>

# %% [markdown]
# ---

# %% [markdown]
# <h3 style="text-align: center;"><b>Компоненты нейросети</b></h3>

# %% [markdown]
# Принципиальную роль в построении любой ***нейронной сети*** играют следующие вещи:
#
# - непосредственно, сама **архитектура** нейросети (сюда входят типы функций активации у каждого нейрона);
# - начальная **инициализация** весов каждого слоя;
# - метод **оптимизации** нейросети (сюда ещё входит метод изменения `learning_rate`);
# - размер **батчей** (`batch_size`);
# - количество итераций обучения (`num_epochs`);
# - **функция потерь** (`loss`);
# - тип **регуляризации** нейросети (для каждого слоя можно свой);
#
# Всё вышеперечисленное мы задаём *руками*, самостоятельно.
#
# То, что связано с ***данными и задачей*** также имеет существенное влияние:
# - само **качество** выборки (непротиворечивость, чистота, корректность постановки задачи);
# - **размер** выборки;

# %% [markdown]
# <h3 style="text-align: center;"><b>Один нейрон на Keras</b></h3>

# %% [markdown]
# В качестве примера возьмём простой набор данных для классификации -- датасет "яблоки и груши":

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("apples_pears.csv")

# %%
plt.figure(figsize=(10, 8))
plt.scatter(data.iloc[:, 0], data.iloc[:, 1], c=data['target'], cmap='rainbow')
plt.title('Яблоки и груши', fontsize=15)
plt.xlabel('симметричность', fontsize=14)
plt.ylabel('желтизна', fontsize=14)
plt.show();

# %%
X = data.iloc[:,:2].values  # матрица объекты-признаки
y = data['target'].values.reshape((-1, 1))  # классы (столбец из нулей и единиц)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.activations import sigmoid

# %%
X[:,:10]
# Out:
# array([[0.77942731, 0.25730527],
#        [0.77700501, 0.0159154 ],
#        [0.97709225, 0.30420962],
#        ...,
#        [0.92721921, 0.13498618],
#        [0.01582991, 0.48132194],
#        [0.96796389, 0.30857107]])

# %%
num_features = X.shape[1]

neuron = Sequential()
neuron.add(Dense(1, input_shape=(num_features,), activation=sigmoid))

# %%
neuron

# %% [markdown]
# Пока что мы просто создали объект класса `Sequential`, который состоит из одного линейного входного слоя размерности (num_features, 1) и 1 нейрона с сигмоидой в качестве активационной функции. Но уже сейчас его можно применить к объекту (тензору), просто веса в начале инициализирутся случайно и при forward_pass'е мы получим какой-то ответ пока что необученного нейрона:

# %%
neuron.predict([[1,1]])
# Out:
# array([[0.2469808]], dtype=float32)

# %% [markdown]
# Выполним предсказания по всем данным с помощью ещё не обученного нейрона:

# %%
proba_pred = neuron.predict(X)
y_pred = proba_pred > 0.5
print(y_pred[:5])
y_pred = y_pred.reshape(-1)

plt.figure(figsize=(10, 8))
plt.scatter(data.iloc[:, 0], data.iloc[:, 1], c=y_pred, cmap='spring')
plt.title('Яблоки и груши', fontsize=15)
plt.xlabel('симметричность', fontsize=14)
plt.ylabel('желтизна', fontsize=14)
plt.show();
# Out:
# [[False]
#  [False]
#  [False]
#  [False]
#  [False]]

# %% [markdown]
# Как и ожидалось, ошибка существенная, по сути, модель не умеет различать классы. Давайте научим нейрон отличать груши от яблок по их симметричности и желтизне!

# %% [markdown]
# ## Код обучения одного нейрона на Keras:

# %% [markdown]
# Обучим нейрон с использованием метода SGD (стохастический градиентный спуск).
# Нам понадобится пакет Keras.optimizers, который содержит различные алгоритмы оптимизации.
#
# Зададим параметры:
# - затухание весов 1e-6
# - момент 0.9
# - включим поддержку ускоренного градиента Нестерова (http://proceedings.mlr.press/v28/sutskever13.pdf)
# - шаг обучения установим равным 0.1
#
# Не забываем накапливать историю обучения - понадобится для построения графиков

# %%
import tensorflow as tf
from tensorflow.keras import optimizers
sgd = optimizers.SGD(decay=1e-6, momentum=0.9, nesterov=True, learning_rate=0.01)
neuron.compile(loss='mean_squared_error', optimizer=sgd, metrics=['accuracy'])
history=neuron.fit(X, y, epochs=100, batch_size=25, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 10ms/step - loss: 0.2433 - accuracy: 0.4588 - val_loss: 0.2222 - val_accuracy: 0.6950
# Epoch 2/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2095 - accuracy: 0.8438 - val_loss: 0.1989 - val_accuracy: 0.8500
# Epoch 3/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1930 - accuracy: 0.8150 - val_loss: 0.1876 - val_accuracy: 0.8100
# Epoch 4/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1835 - accuracy: 0.8062 - val_loss: 0.1787 - val_accuracy: 0.8100
# Epoch 5/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1757 - accuracy: 0.8125 - val_loss: 0.1711 - val_accuracy: 0.8250
# Epoch 6/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1689 - accuracy: 0.8175 - val_loss: 0.1640 - val_accuracy: 0.8300
# Epoch 7/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1626 - accuracy: 0.8438 - val_loss: 0.1577 - val_accuracy: 0.8500
# Epoch 8/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1568 - accuracy: 0.8512 - val_loss: 0.1520 - val_accuracy: 0.8550
# Epoch 9/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1515 - accuracy: 0.8537 - val_loss: 0.1468 - val_accuracy: 0.8600
# Epoch 10/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1467 - accuracy: 0.8600 - val_loss: 0.1419 - val_accuracy: 0.8650
# Epoch 11/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1423 - accuracy: 0.8675 - val_loss: 0.1374 - val_accuracy: 0.8800
# Epoch 12/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1382 - accuracy: 0.8687 - val_loss: 0.1333 - val_accuracy: 0.8800
# Epoch 13/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1344 - accuracy: 0.8737 - val_loss: 0.1295 - val_accuracy: 0.8850
# Epoch 14/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1309 - accuracy: 0.8750 - val_loss: 0.1260 - val_accuracy: 0.8950
# Epoch 15/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1277 - accuracy: 0.8763 - val_loss: 0.1227 - val_accuracy: 0.9050
# Epoch 16/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1247 - accuracy: 0.8825 - val_loss: 0.1197 - val_accuracy: 0.9050
# Epoch 17/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1219 - accuracy: 0.8863 - val_loss: 0.1169 - val_accuracy: 0.9050
# Epoch 18/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1193 - accuracy: 0.8863 - val_loss: 0.1142 - val_accuracy: 0.9050
# Epoch 19/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1168 - accuracy: 0.8888 - val_loss: 0.1117 - val_accuracy: 0.9050
# Epoch 20/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1145 - accuracy: 0.8913 - val_loss: 0.1094 - val_accuracy: 0.9050
# Epoch 21/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1123 - accuracy: 0.8938 - val_loss: 0.1072 - val_accuracy: 0.9100
# Epoch 22/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1103 - accuracy: 0.8963 - val_loss: 0.1051 - val_accuracy: 0.9100
# Epoch 23/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1084 - accuracy: 0.8950 - val_loss: 0.1032 - val_accuracy: 0.9100
# Epoch 24/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1066 - accuracy: 0.8988 - val_loss: 0.1013 - val_accuracy: 0.9150
# Epoch 25/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1049 - accuracy: 0.9000 - val_loss: 0.0995 - val_accuracy: 0.9200
# Epoch 26/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1032 - accuracy: 0.9000 - val_loss: 0.0979 - val_accuracy: 0.9200
# Epoch 27/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1017 - accuracy: 0.9013 - val_loss: 0.0963 - val_accuracy: 0.9250
# Epoch 28/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1002 - accuracy: 0.9038 - val_loss: 0.0948 - val_accuracy: 0.9250
# Epoch 29/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0988 - accuracy: 0.9038 - val_loss: 0.0934 - val_accuracy: 0.9300
# Epoch 30/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0974 - accuracy: 0.9038 - val_loss: 0.0920 - val_accuracy: 0.9300
# Epoch 31/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0962 - accuracy: 0.9062 - val_loss: 0.0907 - val_accuracy: 0.9300
# Epoch 32/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0950 - accuracy: 0.9062 - val_loss: 0.0895 - val_accuracy: 0.9300
# Epoch 33/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0938 - accuracy: 0.9062 - val_loss: 0.0883 - val_accuracy: 0.9300
# Epoch 34/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0926 - accuracy: 0.9087 - val_loss: 0.0871 - val_accuracy: 0.9300
# Epoch 35/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0916 - accuracy: 0.9075 - val_loss: 0.0860 - val_accuracy: 0.9400
# Epoch 36/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0905 - accuracy: 0.9087 - val_loss: 0.0849 - val_accuracy: 0.9400
# Epoch 37/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0895 - accuracy: 0.9112 - val_loss: 0.0839 - val_accuracy: 0.9400
# Epoch 38/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0886 - accuracy: 0.9125 - val_loss: 0.0829 - val_accuracy: 0.9400
# Epoch 39/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0877 - accuracy: 0.9125 - val_loss: 0.0820 - val_accuracy: 0.9400
# Epoch 40/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0868 - accuracy: 0.9150 - val_loss: 0.0811 - val_accuracy: 0.9400
# Epoch 41/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0860 - accuracy: 0.9162 - val_loss: 0.0802 - val_accuracy: 0.9450
# Epoch 42/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0851 - accuracy: 0.9162 - val_loss: 0.0793 - val_accuracy: 0.9400
# Epoch 43/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0843 - accuracy: 0.9162 - val_loss: 0.0785 - val_accuracy: 0.9450
# Epoch 44/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0835 - accuracy: 0.9162 - val_loss: 0.0777 - val_accuracy: 0.9450
# Epoch 45/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0828 - accuracy: 0.9175 - val_loss: 0.0769 - val_accuracy: 0.9500
# Epoch 46/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0821 - accuracy: 0.9187 - val_loss: 0.0762 - val_accuracy: 0.9500
# Epoch 47/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0814 - accuracy: 0.9212 - val_loss: 0.0755 - val_accuracy: 0.9500
# Epoch 48/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0807 - accuracy: 0.9200 - val_loss: 0.0747 - val_accuracy: 0.9500
# Epoch 49/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0800 - accuracy: 0.9200 - val_loss: 0.0741 - val_accuracy: 0.9500
# Epoch 50/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0794 - accuracy: 0.9225 - val_loss: 0.0734 - val_accuracy: 0.9500
# Epoch 51/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0788 - accuracy: 0.9225 - val_loss: 0.0728 - val_accuracy: 0.9500
# Epoch 52/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0782 - accuracy: 0.9225 - val_loss: 0.0721 - val_accuracy: 0.9500
# Epoch 53/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0776 - accuracy: 0.9237 - val_loss: 0.0716 - val_accuracy: 0.9500
# Epoch 54/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0770 - accuracy: 0.9250 - val_loss: 0.0710 - val_accuracy: 0.9500
# Epoch 55/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0765 - accuracy: 0.9262 - val_loss: 0.0704 - val_accuracy: 0.9500
# Epoch 56/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0759 - accuracy: 0.9262 - val_loss: 0.0698 - val_accuracy: 0.9500
# Epoch 57/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0754 - accuracy: 0.9275 - val_loss: 0.0693 - val_accuracy: 0.9500
# Epoch 58/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0749 - accuracy: 0.9287 - val_loss: 0.0687 - val_accuracy: 0.9500
# Epoch 59/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0744 - accuracy: 0.9287 - val_loss: 0.0682 - val_accuracy: 0.9500
# Epoch 60/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0739 - accuracy: 0.9312 - val_loss: 0.0677 - val_accuracy: 0.9500
# Epoch 61/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0734 - accuracy: 0.9312 - val_loss: 0.0672 - val_accuracy: 0.9500
# Epoch 62/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0730 - accuracy: 0.9312 - val_loss: 0.0667 - val_accuracy: 0.9500
# Epoch 63/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0725 - accuracy: 0.9312 - val_loss: 0.0663 - val_accuracy: 0.9500
# Epoch 64/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0720 - accuracy: 0.9312 - val_loss: 0.0658 - val_accuracy: 0.9500
# Epoch 65/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0716 - accuracy: 0.9325 - val_loss: 0.0654 - val_accuracy: 0.9500
# Epoch 66/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0712 - accuracy: 0.9337 - val_loss: 0.0650 - val_accuracy: 0.9500
# Epoch 67/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0708 - accuracy: 0.9325 - val_loss: 0.0645 - val_accuracy: 0.9500
# Epoch 68/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0704 - accuracy: 0.9337 - val_loss: 0.0641 - val_accuracy: 0.9500
# Epoch 69/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0700 - accuracy: 0.9337 - val_loss: 0.0636 - val_accuracy: 0.9500
# Epoch 70/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0696 - accuracy: 0.9337 - val_loss: 0.0633 - val_accuracy: 0.9500
# Epoch 71/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0692 - accuracy: 0.9350 - val_loss: 0.0629 - val_accuracy: 0.9500
# Epoch 72/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0688 - accuracy: 0.9350 - val_loss: 0.0625 - val_accuracy: 0.9500
# Epoch 73/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0685 - accuracy: 0.9350 - val_loss: 0.0621 - val_accuracy: 0.9500
# Epoch 74/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0681 - accuracy: 0.9350 - val_loss: 0.0617 - val_accuracy: 0.9500
# Epoch 75/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0678 - accuracy: 0.9350 - val_loss: 0.0614 - val_accuracy: 0.9500
# Epoch 76/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0675 - accuracy: 0.9350 - val_loss: 0.0610 - val_accuracy: 0.9500
# Epoch 77/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0671 - accuracy: 0.9350 - val_loss: 0.0607 - val_accuracy: 0.9500
# Epoch 78/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0668 - accuracy: 0.9350 - val_loss: 0.0603 - val_accuracy: 0.9500
# Epoch 79/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0664 - accuracy: 0.9350 - val_loss: 0.0600 - val_accuracy: 0.9500
# Epoch 80/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0661 - accuracy: 0.9350 - val_loss: 0.0596 - val_accuracy: 0.9500
# Epoch 81/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0658 - accuracy: 0.9350 - val_loss: 0.0593 - val_accuracy: 0.9500
# Epoch 82/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0655 - accuracy: 0.9350 - val_loss: 0.0590 - val_accuracy: 0.9500
# Epoch 83/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0652 - accuracy: 0.9350 - val_loss: 0.0587 - val_accuracy: 0.9500
# Epoch 84/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0649 - accuracy: 0.9350 - val_loss: 0.0584 - val_accuracy: 0.9500
# Epoch 85/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0647 - accuracy: 0.9362 - val_loss: 0.0581 - val_accuracy: 0.9500
# Epoch 86/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0644 - accuracy: 0.9350 - val_loss: 0.0578 - val_accuracy: 0.9500
# Epoch 87/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0641 - accuracy: 0.9350 - val_loss: 0.0575 - val_accuracy: 0.9500
# Epoch 88/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0638 - accuracy: 0.9375 - val_loss: 0.0572 - val_accuracy: 0.9500
# Epoch 89/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0635 - accuracy: 0.9362 - val_loss: 0.0569 - val_accuracy: 0.9500
# Epoch 90/100
# 32/32 [==============================] - 0s 9ms/step - loss: 0.0633 - accuracy: 0.9375 - val_loss: 0.0566 - val_accuracy: 0.9500
# Epoch 91/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0630 - accuracy: 0.9375 - val_loss: 0.0564 - val_accuracy: 0.9500
# Epoch 92/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0628 - accuracy: 0.9375 - val_loss: 0.0561 - val_accuracy: 0.9500
# Epoch 93/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0625 - accuracy: 0.9388 - val_loss: 0.0559 - val_accuracy: 0.9500
# Epoch 94/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0622 - accuracy: 0.9388 - val_loss: 0.0556 - val_accuracy: 0.9500
# Epoch 95/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0620 - accuracy: 0.9388 - val_loss: 0.0553 - val_accuracy: 0.9500
# Epoch 96/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0618 - accuracy: 0.9388 - val_loss: 0.0551 - val_accuracy: 0.9500
# Epoch 97/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0615 - accuracy: 0.9388 - val_loss: 0.0548 - val_accuracy: 0.9500
# Epoch 98/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0613 - accuracy: 0.9400 - val_loss: 0.0546 - val_accuracy: 0.9500
# Epoch 99/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0610 - accuracy: 0.9400 - val_loss: 0.0543 - val_accuracy: 0.9500
# Epoch 100/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0608 - accuracy: 0.9400 - val_loss: 0.0541 - val_accuracy: 0.9500

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
#plt.legend(['train','test'])
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
#plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# Обучили. Снова выполним предсказания, но уже с помощью обученной модели.

# %%
proba_pred = neuron.predict(X)
y_pred = proba_pred > 0.5
y_pred = y_pred.reshape(-1)

plt.figure(figsize=(10, 8))
plt.scatter(data.iloc[:, 0], data.iloc[:, 1], c=y_pred, cmap='spring')
plt.title('Яблоки и груши', fontsize=15)
plt.xlabel('симметричность', fontsize=14)
plt.ylabel('желтизна', fontsize=14)
plt.show();

# %% [markdown]
# <h2 style="text-align: center;"><b>Многослойная сеть на Keras</b></h3>

# %% [markdown]
# ---

# %% [markdown]
# ## Многослойная нейронная сеть

# %% [markdown]
# Как можно понять из названия, многослойная нейросеть состоит из нескольких **слоёв**. Ещё такую многослойную нейросеть, у которой каждый нейрон на предыдущем уровне соединён с нейроном на следующем уровне, называют ***Fully-Connected-сетью*** (или ***Dense-сетью***).
#
# Расмотрим их устройство более подробно:

# %% [markdown]
# * Вот так выглядит двухслойная нейросеть (первый слой - input layer - не считается, потому что это, по сути, не слой):

# %% [markdown]
# <img src="http://cs231n.github.io/assets/nn1/neural_net.jpeg" width=300, height=200>

# %% [markdown]
# * Так выглядит трёхслойная нейросеть:

# %% [markdown]
# <img src="http://cs231n.github.io/assets/nn1/neural_net2.jpeg" width=400, height=300>

# %% [markdown]
# .. и так далее для большего случая слоёв.

# %% [markdown]
# **Обратите внимание:** связи есть от каждого нейрона слоя $L_{i-1}$ к каждому нейрону слоя $L_{i}$, но между нейронами в одном слое связей **нет**.

# %% [markdown]
# **Входной слой** -- это данные (матрица $(n, m)$).

# %% [markdown]
# Слои, которые не являются входными или выходными, называются **скрытыми слоями (hidden layers)**.

# %% [markdown]
# При решении ***задачи регрессии*** в **выходном слое** есть только один нейрон, который возвращает предсказанные числа (для каждого объекта по числу).
#
# В случае решения ***задачи классификации*** в **выходном слое** может быть как один, так и несколько нейронов. Если решается задача бинарной классификации, то слой содержит один нейрон и $K$ нейронов, если решается задача $K$-класовой классификации.

# %% [markdown]
# #### Прямое распространение

# %% [markdown]
# Каждый слой многослойной нейросети - это матрица весов, столбцы которой -- это нейроны (один столбец - один нейрон). То есть один столбец -- это веса одного нейрона.

# %% [markdown]
# Допустим, мы решаем задачу $K$-классовой классификации (на последнем слое $K$ нейронов). Рассмотрим, как в таком случае выглядит `forward_pass` нейросети:

# %% [markdown]
# * Вход: $$X =
# \left(
# \begin{matrix}
# x_{11} & ... & x_{1M} \\
# ... & \ddots  & ...\\
# x_{N1} & ... & x_{NM}
# \end{matrix}
# \right)
# $$
#
# -- матрица $(N, M)$

# %% [markdown]
# * Структура сети - много слоёв, в слоях много нейронов. Первый слой (после входного) выглядит так:

# %% [markdown]
# $$ W^1 =
# \left(
# \begin{matrix}
# w_{11} & ... & w_{1L_1} \\
# ... & \ddots  & ...\\
# w_{M1} & ... & w_{ML_1}
# \end{matrix}
# \right)
# $$
#
# -- матрица $(M, L_1)$

# %% [markdown]
# То есть это в точности $L_1$ нейронов, каждый имеет свои собственные веса, их $M$ штук.

# %% [markdown]
# Мы помним, что нейрон - это линейное преобразование и потом нелинейная функция активации от этого преобразования. Однако в многослойных нейростеях часто отделяют `Linear` часть и `Activation`, то есть слоем считаем набор весов нейронов, а следующий слой всегда функция активации (у всех нейронов из слоя она одна и та же, обычно фреймворки не позволяют задавать конкретному нейрону в слое отличную от других нейронов в этом слое функцию активации, однако это легко сделать, объявив слой из одного нейрона).

# %% [markdown]
# * Другие слои выглядит точно так же, как первый слой. Например, второй слой будет такой:

# %% [markdown]
# $$ W^2 =
# \left(
# \begin{matrix}
# w_{11} & ... & w_{1L_2} \\
# ... & \ddots  & ...\\
# w_{L_11} & ... & w_{L_1L_2}
# \end{matrix}
# \right)
# $$
#
# -- матрица $(L_1, L_2)$

# %% [markdown]
# То есть это в точности $L_2$ нейронов, каждый имеет свои собственные веса, их $L_1$ штук.

# %% [markdown]
# * Выходной слой:
#
# Пусть в нейросети до выходного слоя идут $t$ слоёв. Тогда выходной слой имеет форму:

# %% [markdown]
# $$ W^{out} =
# \left(
# \begin{matrix}
# w_{11} & ... & w_{1K} \\
# ... & \ddots  & ...\\
# w_{L_t1} & ... & w_{L_tK}
# \end{matrix}
# \right)
# $$
#
# -- матрица $(L_t, K)$, где $L_t$ - количество нейронов в $t$-ом слое, а $K$ -- количество классов.

# %% [markdown]
# В итоге *для `forward_pass` нам нужно просто последовтельно перемножить матрицы друг за другом, применяя после каждого умножения соответсвующую функцию активации*.

# %% [markdown]
# *Примечание*: можно думать об умножении на очередную матрицу весов как на переход в **новое признаковое пространство**. Действительно, когда подаём матрицу $X$ и умножаем на матрицу первого слоя, мы получаем матрицу размера $(N, L_1)$, то есть как будто $L_1$ "новых" признаков (построенных как линейная комбинация старых до применения функции активации, и уже как нелинейная комбинация после активации). Здесь уместно вспомнить, что Deep Learning является пообластью Representation Learning, то есть позволяет выучивает новые представляения данных.

# %% [markdown]
# **Обратное распространение**

# %% [markdown]
# Обучается с помощью метода "Error Backpropagation" - ["Обратное распространение ошибки"](https://ru.wikipedia.org/wiki/%D0%9C%D0%B5%D1%82%D0%BE%D0%B4_%D0%BE%D0%B1%D1%80%D0%B0%D1%82%D0%BD%D0%BE%D0%B3%D0%BE_%D1%80%D0%B0%D1%81%D0%BF%D1%80%D0%BE%D1%81%D1%82%D1%80%D0%B0%D0%BD%D0%B5%D0%BD%D0%B8%D1%8F_%D0%BE%D1%88%D0%B8%D0%B1%D0%BA%D0%B8), принцип распространения очень похож на то, как мы обучали один нейрон - это градиентный спуск, но по "всей нейросети" сразу.

# %% [markdown]
# Backpropagation работает корректно благодаря ***chain rule*** (=правилу взятия производной сложной функции):
#
# Если $f(x) = f(g(x))$, то:
#
# $$\frac{\partial{f}}{\partial{x}} = \frac{\partial{f}}{\partial{g}} \frac{\partial{g}}{\partial{x}}$$

# %% [markdown]
# Более подробно про backpropagation можно прочитать здесь (на английском):  https://mattmazur.com/2015/03/17/a-step-by-step-backpropagation-example/

# %% [markdown]
# # Создание двухслойной нейросети
# Cоздадим двухслойную нейросеть из 100 нейронов:

# %%
import matplotlib.pyplot as plt
import numpy as np

import keras

# %% [markdown]
# Генерация датасета:

# %%
N = 100
D = 2
K = 3
X = np.zeros((N * K, D))
y = np.zeros(N * K, dtype='uint8')

for j in range(K):
    ix = range(N * j,N * (j + 1))
    r = np.linspace(0.0, 1, N)
    t = np.linspace(j * 4, (j + 1) * 4,N) + np.random.randn(N) * 0.2 # theta
    X[ix] = np.c_[r * np.sin(t), r * np.cos(t)]
    y[ix] = j

# %%
plt.figure(figsize=(10, 8))
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.rainbow)
plt.title('Спираль', fontsize=15)
plt.xlabel('$x$', fontsize=14)
plt.ylabel('$y$', fontsize=14)
plt.show();

# %%
print(X.data.shape, y.data.shape)
# Out:
# (300, 2) (300,)

# %%
from keras.utils import np_utils
y = keras.utils.np_utils.to_categorical(y, 3)

# %%
from keras import optimizers
two_layer_net=keras.models.Sequential()
two_layer_net.add(keras.layers.Dense(100, input_shape=(X.shape[1],), activation='relu'))
two_layer_net.add(keras.layers.Dense(3, activation='softmax'))
print(two_layer_net.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 100)               300
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 603
# Trainable params: 603
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#визуализация модели
from keras.utils.vis_utils import plot_model
plot_model(two_layer_net, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
from tensorflow.keras import optimizers
sgd = optimizers.SGD(decay=1e-6, momentum=0.9, nesterov=True, learning_rate=0.01)
two_layer_net.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
history=two_layer_net.fit(X, y, epochs=150, batch_size=64, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/150
# 4/4 [==============================] - 1s 67ms/step - loss: 1.0756 - accuracy: 0.4542 - val_loss: 1.1659 - val_accuracy: 0.0000e+00
# Epoch 2/150
# 4/4 [==============================] - 0s 19ms/step - loss: 1.0593 - accuracy: 0.5292 - val_loss: 1.2127 - val_accuracy: 0.0000e+00
# Epoch 3/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.0354 - accuracy: 0.5875 - val_loss: 1.2690 - val_accuracy: 0.0000e+00
# Epoch 4/150
# 4/4 [==============================] - 0s 18ms/step - loss: 1.0100 - accuracy: 0.6208 - val_loss: 1.3307 - val_accuracy: 0.0000e+00
# Epoch 5/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.9843 - accuracy: 0.6250 - val_loss: 1.3917 - val_accuracy: 0.0000e+00
# Epoch 6/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.9621 - accuracy: 0.6208 - val_loss: 1.4520 - val_accuracy: 0.0000e+00
# Epoch 7/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.9411 - accuracy: 0.6083 - val_loss: 1.5066 - val_accuracy: 0.0000e+00
# Epoch 8/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.9236 - accuracy: 0.6000 - val_loss: 1.5550 - val_accuracy: 0.0000e+00
# Epoch 9/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.9077 - accuracy: 0.6083 - val_loss: 1.5974 - val_accuracy: 0.0000e+00
# Epoch 10/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.8939 - accuracy: 0.6042 - val_loss: 1.6344 - val_accuracy: 0.0000e+00
# Epoch 11/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.8805 - accuracy: 0.6083 - val_loss: 1.6650 - val_accuracy: 0.0000e+00
# Epoch 12/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.8682 - accuracy: 0.5958 - val_loss: 1.6897 - val_accuracy: 0.0000e+00
# Epoch 13/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.8568 - accuracy: 0.6042 - val_loss: 1.7078 - val_accuracy: 0.0000e+00
# Epoch 14/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.8462 - accuracy: 0.6000 - val_loss: 1.7245 - val_accuracy: 0.0000e+00
# Epoch 15/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.8361 - accuracy: 0.5958 - val_loss: 1.7418 - val_accuracy: 0.0000e+00
# Epoch 16/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.8264 - accuracy: 0.5958 - val_loss: 1.7533 - val_accuracy: 0.0000e+00
# Epoch 17/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.8174 - accuracy: 0.5917 - val_loss: 1.7678 - val_accuracy: 0.0000e+00
# Epoch 18/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.8088 - accuracy: 0.6042 - val_loss: 1.7787 - val_accuracy: 0.0000e+00
# Epoch 19/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.8005 - accuracy: 0.6042 - val_loss: 1.7895 - val_accuracy: 0.0000e+00
# Epoch 20/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.7929 - accuracy: 0.6042 - val_loss: 1.7981 - val_accuracy: 0.0000e+00
# Epoch 21/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.7858 - accuracy: 0.6042 - val_loss: 1.8075 - val_accuracy: 0.0000e+00
# Epoch 22/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.7789 - accuracy: 0.6042 - val_loss: 1.8157 - val_accuracy: 0.0000e+00
# Epoch 23/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.7724 - accuracy: 0.6000 - val_loss: 1.8278 - val_accuracy: 0.0000e+00
# Epoch 24/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.7660 - accuracy: 0.5958 - val_loss: 1.8336 - val_accuracy: 0.0000e+00
# Epoch 25/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.7604 - accuracy: 0.5958 - val_loss: 1.8404 - val_accuracy: 0.0000e+00
# Epoch 26/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.7553 - accuracy: 0.5958 - val_loss: 1.8442 - val_accuracy: 0.0000e+00
# Epoch 27/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.7497 - accuracy: 0.5958 - val_loss: 1.8551 - val_accuracy: 0.0000e+00
# Epoch 28/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.7449 - accuracy: 0.6000 - val_loss: 1.8642 - val_accuracy: 0.0000e+00
# Epoch 29/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.7400 - accuracy: 0.5958 - val_loss: 1.8715 - val_accuracy: 0.0000e+00
# Epoch 30/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.7354 - accuracy: 0.5958 - val_loss: 1.8821 - val_accuracy: 0.0000e+00
# Epoch 31/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.7308 - accuracy: 0.6000 - val_loss: 1.8939 - val_accuracy: 0.0000e+00
# Epoch 32/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.7268 - accuracy: 0.6000 - val_loss: 1.9026 - val_accuracy: 0.0000e+00
# Epoch 33/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.7230 - accuracy: 0.6000 - val_loss: 1.9110 - val_accuracy: 0.0000e+00
# Epoch 34/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.7194 - accuracy: 0.5958 - val_loss: 1.9235 - val_accuracy: 0.0000e+00
# Epoch 35/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.7159 - accuracy: 0.5958 - val_loss: 1.9362 - val_accuracy: 0.0000e+00
# Epoch 36/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.7125 - accuracy: 0.6000 - val_loss: 1.9500 - val_accuracy: 0.0000e+00
# Epoch 37/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.7093 - accuracy: 0.6000 - val_loss: 1.9626 - val_accuracy: 0.0000e+00
# Epoch 38/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.7065 - accuracy: 0.6000 - val_loss: 1.9779 - val_accuracy: 0.0000e+00
# Epoch 39/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.7034 - accuracy: 0.6000 - val_loss: 1.9894 - val_accuracy: 0.0000e+00
# Epoch 40/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.7007 - accuracy: 0.6000 - val_loss: 1.9965 - val_accuracy: 0.0000e+00
# Epoch 41/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6980 - accuracy: 0.6000 - val_loss: 2.0065 - val_accuracy: 0.0000e+00
# Epoch 42/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6951 - accuracy: 0.6000 - val_loss: 2.0182 - val_accuracy: 0.0000e+00
# Epoch 43/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6927 - accuracy: 0.6042 - val_loss: 2.0287 - val_accuracy: 0.0000e+00
# Epoch 44/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6904 - accuracy: 0.6000 - val_loss: 2.0412 - val_accuracy: 0.0000e+00
# Epoch 45/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6877 - accuracy: 0.6000 - val_loss: 2.0489 - val_accuracy: 0.0000e+00
# Epoch 46/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6856 - accuracy: 0.6000 - val_loss: 2.0587 - val_accuracy: 0.0000e+00
# Epoch 47/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6833 - accuracy: 0.6042 - val_loss: 2.0691 - val_accuracy: 0.0000e+00
# Epoch 48/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6812 - accuracy: 0.6083 - val_loss: 2.0827 - val_accuracy: 0.0000e+00
# Epoch 49/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6791 - accuracy: 0.6083 - val_loss: 2.1045 - val_accuracy: 0.0000e+00
# Epoch 50/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.6769 - accuracy: 0.6042 - val_loss: 2.1216 - val_accuracy: 0.0000e+00
# Epoch 51/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6750 - accuracy: 0.6042 - val_loss: 2.1341 - val_accuracy: 0.0000e+00
# Epoch 52/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6729 - accuracy: 0.6042 - val_loss: 2.1515 - val_accuracy: 0.0000e+00
# Epoch 53/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6710 - accuracy: 0.6042 - val_loss: 2.1677 - val_accuracy: 0.0000e+00
# Epoch 54/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6692 - accuracy: 0.6083 - val_loss: 2.1842 - val_accuracy: 0.0000e+00
# Epoch 55/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6676 - accuracy: 0.6042 - val_loss: 2.1985 - val_accuracy: 0.0000e+00
# Epoch 56/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6662 - accuracy: 0.6125 - val_loss: 2.2125 - val_accuracy: 0.0000e+00
# Epoch 57/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6637 - accuracy: 0.6125 - val_loss: 2.2234 - val_accuracy: 0.0000e+00
# Epoch 58/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6618 - accuracy: 0.6083 - val_loss: 2.2379 - val_accuracy: 0.0000e+00
# Epoch 59/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6603 - accuracy: 0.6083 - val_loss: 2.2502 - val_accuracy: 0.0000e+00
# Epoch 60/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6585 - accuracy: 0.6167 - val_loss: 2.2682 - val_accuracy: 0.0000e+00
# Epoch 61/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6568 - accuracy: 0.6167 - val_loss: 2.2926 - val_accuracy: 0.0000e+00
# Epoch 62/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6553 - accuracy: 0.6125 - val_loss: 2.3142 - val_accuracy: 0.0000e+00
# Epoch 63/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6530 - accuracy: 0.6167 - val_loss: 2.3267 - val_accuracy: 0.0000e+00
# Epoch 64/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6515 - accuracy: 0.6167 - val_loss: 2.3336 - val_accuracy: 0.0000e+00
# Epoch 65/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6498 - accuracy: 0.6167 - val_loss: 2.3451 - val_accuracy: 0.0000e+00
# Epoch 66/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6483 - accuracy: 0.6167 - val_loss: 2.3564 - val_accuracy: 0.0000e+00
# Epoch 67/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6465 - accuracy: 0.6208 - val_loss: 2.3716 - val_accuracy: 0.0000e+00
# Epoch 68/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6447 - accuracy: 0.6208 - val_loss: 2.3892 - val_accuracy: 0.0000e+00
# Epoch 69/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6435 - accuracy: 0.6250 - val_loss: 2.4144 - val_accuracy: 0.0000e+00
# Epoch 70/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6415 - accuracy: 0.6208 - val_loss: 2.4285 - val_accuracy: 0.0000e+00
# Epoch 71/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6401 - accuracy: 0.6208 - val_loss: 2.4411 - val_accuracy: 0.0000e+00
# Epoch 72/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6379 - accuracy: 0.6250 - val_loss: 2.4499 - val_accuracy: 0.0000e+00
# Epoch 73/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6365 - accuracy: 0.6250 - val_loss: 2.4579 - val_accuracy: 0.0000e+00
# Epoch 74/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.6345 - accuracy: 0.6250 - val_loss: 2.4741 - val_accuracy: 0.0000e+00
# Epoch 75/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6334 - accuracy: 0.6250 - val_loss: 2.4927 - val_accuracy: 0.0000e+00
# Epoch 76/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6315 - accuracy: 0.6208 - val_loss: 2.5055 - val_accuracy: 0.0000e+00
# Epoch 77/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6299 - accuracy: 0.6250 - val_loss: 2.5201 - val_accuracy: 0.0000e+00
# Epoch 78/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6281 - accuracy: 0.6250 - val_loss: 2.5424 - val_accuracy: 0.0000e+00
# Epoch 79/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6265 - accuracy: 0.6292 - val_loss: 2.5697 - val_accuracy: 0.0000e+00
# Epoch 80/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6252 - accuracy: 0.6292 - val_loss: 2.5888 - val_accuracy: 0.0000e+00
# Epoch 81/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.6229 - accuracy: 0.6333 - val_loss: 2.5970 - val_accuracy: 0.0000e+00
# Epoch 82/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.6215 - accuracy: 0.6292 - val_loss: 2.6071 - val_accuracy: 0.0000e+00
# Epoch 83/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6198 - accuracy: 0.6292 - val_loss: 2.6228 - val_accuracy: 0.0000e+00
# Epoch 84/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6180 - accuracy: 0.6292 - val_loss: 2.6407 - val_accuracy: 0.0000e+00
# Epoch 85/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6165 - accuracy: 0.6375 - val_loss: 2.6597 - val_accuracy: 0.0000e+00
# Epoch 86/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6149 - accuracy: 0.6333 - val_loss: 2.6849 - val_accuracy: 0.0000e+00
# Epoch 87/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6131 - accuracy: 0.6333 - val_loss: 2.7000 - val_accuracy: 0.0000e+00
# Epoch 88/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6118 - accuracy: 0.6375 - val_loss: 2.7204 - val_accuracy: 0.0000e+00
# Epoch 89/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6099 - accuracy: 0.6375 - val_loss: 2.7437 - val_accuracy: 0.0000e+00
# Epoch 90/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6081 - accuracy: 0.6417 - val_loss: 2.7652 - val_accuracy: 0.0000e+00
# Epoch 91/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6065 - accuracy: 0.6333 - val_loss: 2.7882 - val_accuracy: 0.0000e+00
# Epoch 92/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6047 - accuracy: 0.6417 - val_loss: 2.8062 - val_accuracy: 0.0000e+00
# Epoch 93/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6032 - accuracy: 0.6458 - val_loss: 2.8245 - val_accuracy: 0.0000e+00
# Epoch 94/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6014 - accuracy: 0.6458 - val_loss: 2.8444 - val_accuracy: 0.0000e+00
# Epoch 95/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6001 - accuracy: 0.6458 - val_loss: 2.8612 - val_accuracy: 0.0000e+00
# Epoch 96/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5983 - accuracy: 0.6417 - val_loss: 2.8874 - val_accuracy: 0.0000e+00
# Epoch 97/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5964 - accuracy: 0.6458 - val_loss: 2.9073 - val_accuracy: 0.0000e+00
# Epoch 98/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5948 - accuracy: 0.6458 - val_loss: 2.9323 - val_accuracy: 0.0000e+00
# Epoch 99/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5933 - accuracy: 0.6458 - val_loss: 2.9554 - val_accuracy: 0.0000e+00
# Epoch 100/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5915 - accuracy: 0.6542 - val_loss: 2.9791 - val_accuracy: 0.0000e+00
# Epoch 101/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5896 - accuracy: 0.6542 - val_loss: 2.9954 - val_accuracy: 0.0000e+00
# Epoch 102/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5880 - accuracy: 0.6500 - val_loss: 3.0160 - val_accuracy: 0.0000e+00
# Epoch 103/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5862 - accuracy: 0.6500 - val_loss: 3.0352 - val_accuracy: 0.0000e+00
# Epoch 104/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5845 - accuracy: 0.6542 - val_loss: 3.0523 - val_accuracy: 0.0000e+00
# Epoch 105/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5829 - accuracy: 0.6500 - val_loss: 3.0653 - val_accuracy: 0.0000e+00
# Epoch 106/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5810 - accuracy: 0.6542 - val_loss: 3.0796 - val_accuracy: 0.0000e+00
# Epoch 107/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5793 - accuracy: 0.6542 - val_loss: 3.1010 - val_accuracy: 0.0000e+00
# Epoch 108/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5781 - accuracy: 0.6542 - val_loss: 3.1224 - val_accuracy: 0.0000e+00
# Epoch 109/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5761 - accuracy: 0.6542 - val_loss: 3.1528 - val_accuracy: 0.0000e+00
# Epoch 110/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5743 - accuracy: 0.6542 - val_loss: 3.1821 - val_accuracy: 0.0000e+00
# Epoch 111/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5723 - accuracy: 0.6583 - val_loss: 3.2095 - val_accuracy: 0.0000e+00
# Epoch 112/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5708 - accuracy: 0.6625 - val_loss: 3.2333 - val_accuracy: 0.0000e+00
# Epoch 113/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5692 - accuracy: 0.6667 - val_loss: 3.2604 - val_accuracy: 0.0000e+00
# Epoch 114/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5671 - accuracy: 0.6583 - val_loss: 3.2757 - val_accuracy: 0.0000e+00
# Epoch 115/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5655 - accuracy: 0.6667 - val_loss: 3.2880 - val_accuracy: 0.0000e+00
# Epoch 116/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5635 - accuracy: 0.6625 - val_loss: 3.2948 - val_accuracy: 0.0000e+00
# Epoch 117/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5619 - accuracy: 0.6583 - val_loss: 3.3068 - val_accuracy: 0.0000e+00
# Epoch 118/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5602 - accuracy: 0.6583 - val_loss: 3.3248 - val_accuracy: 0.0000e+00
# Epoch 119/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5583 - accuracy: 0.6667 - val_loss: 3.3505 - val_accuracy: 0.0000e+00
# Epoch 120/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5566 - accuracy: 0.6708 - val_loss: 3.3868 - val_accuracy: 0.0000e+00
# Epoch 121/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5549 - accuracy: 0.6667 - val_loss: 3.4211 - val_accuracy: 0.0000e+00
# Epoch 122/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5533 - accuracy: 0.6708 - val_loss: 3.4469 - val_accuracy: 0.0000e+00
# Epoch 123/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5518 - accuracy: 0.6792 - val_loss: 3.4726 - val_accuracy: 0.0000e+00
# Epoch 124/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5496 - accuracy: 0.6708 - val_loss: 3.4968 - val_accuracy: 0.0000e+00
# Epoch 125/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5482 - accuracy: 0.6667 - val_loss: 3.5180 - val_accuracy: 0.0000e+00
# Epoch 126/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5461 - accuracy: 0.6708 - val_loss: 3.5381 - val_accuracy: 0.0000e+00
# Epoch 127/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5442 - accuracy: 0.6792 - val_loss: 3.5539 - val_accuracy: 0.0000e+00
# Epoch 128/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5425 - accuracy: 0.6833 - val_loss: 3.5784 - val_accuracy: 0.0000e+00
# Epoch 129/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5406 - accuracy: 0.6875 - val_loss: 3.5969 - val_accuracy: 0.0000e+00
# Epoch 130/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5388 - accuracy: 0.6917 - val_loss: 3.6161 - val_accuracy: 0.0000e+00
# Epoch 131/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5371 - accuracy: 0.6958 - val_loss: 3.6360 - val_accuracy: 0.0000e+00
# Epoch 132/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5352 - accuracy: 0.6958 - val_loss: 3.6631 - val_accuracy: 0.0000e+00
# Epoch 133/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5340 - accuracy: 0.6958 - val_loss: 3.6915 - val_accuracy: 0.0000e+00
# Epoch 134/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5320 - accuracy: 0.6958 - val_loss: 3.7216 - val_accuracy: 0.0000e+00
# Epoch 135/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5299 - accuracy: 0.6958 - val_loss: 3.7564 - val_accuracy: 0.0000e+00
# Epoch 136/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5281 - accuracy: 0.7000 - val_loss: 3.7880 - val_accuracy: 0.0000e+00
# Epoch 137/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5264 - accuracy: 0.7000 - val_loss: 3.8114 - val_accuracy: 0.0000e+00
# Epoch 138/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5246 - accuracy: 0.7000 - val_loss: 3.8297 - val_accuracy: 0.0000e+00
# Epoch 139/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5228 - accuracy: 0.7000 - val_loss: 3.8516 - val_accuracy: 0.0000e+00
# Epoch 140/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5212 - accuracy: 0.6958 - val_loss: 3.8664 - val_accuracy: 0.0000e+00
# Epoch 141/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5194 - accuracy: 0.6958 - val_loss: 3.8863 - val_accuracy: 0.0000e+00
# Epoch 142/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5174 - accuracy: 0.7000 - val_loss: 3.9163 - val_accuracy: 0.0000e+00
# Epoch 143/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5160 - accuracy: 0.7000 - val_loss: 3.9464 - val_accuracy: 0.0000e+00
# Epoch 144/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5137 - accuracy: 0.7042 - val_loss: 3.9808 - val_accuracy: 0.0000e+00
# Epoch 145/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5121 - accuracy: 0.7042 - val_loss: 4.0082 - val_accuracy: 0.0000e+00
# Epoch 146/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5104 - accuracy: 0.7042 - val_loss: 4.0381 - val_accuracy: 0.0000e+00
# Epoch 147/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5088 - accuracy: 0.7042 - val_loss: 4.0692 - val_accuracy: 0.0000e+00
# Epoch 148/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5072 - accuracy: 0.7042 - val_loss: 4.1007 - val_accuracy: 0.0000e+00
# Epoch 149/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5052 - accuracy: 0.7083 - val_loss: 4.1252 - val_accuracy: 0.0000e+00
# Epoch 150/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5033 - accuracy: 0.7083 - val_loss: 4.1478 - val_accuracy: 0.0000e+00

# %%
plt.plot(history.history['accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
#plt.legend(['train','test'])
plt.show()

# %% [markdown]
# # Создание многослойной нейросети
# Усложним архитектуру нейронной сети прямого распространения:

# %%
many_layer_net=keras.models.Sequential()
two_layer_net.add(keras.layers.Dense(100, input_shape=(X.shape[1],), activation='relu'))
two_layer_net.add(keras.layers.Dense(100, activation='relu'))

two_layer_net.add(keras.layers.Dense(100, activation='relu'))
two_layer_net.add(keras.layers.Dense(3, activation='softmax'))
sgd = optimizers.SGD(decay=1e-6, momentum=0.9, nesterov=True, learning_rate=0.001)
two_layer_net.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
history=two_layer_net.fit(X, y, epochs=150, batch_size=64, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/150
# 4/4 [==============================] - 1s 89ms/step - loss: 1.1089 - accuracy: 0.4167 - val_loss: 1.1146 - val_accuracy: 0.0000e+00
# Epoch 2/150
# 4/4 [==============================] - 0s 24ms/step - loss: 1.1045 - accuracy: 0.4167 - val_loss: 1.1265 - val_accuracy: 0.0000e+00
# Epoch 3/150
# 4/4 [==============================] - 0s 24ms/step - loss: 1.0976 - accuracy: 0.4167 - val_loss: 1.1411 - val_accuracy: 0.0000e+00
# Epoch 4/150
# 4/4 [==============================] - 0s 30ms/step - loss: 1.0902 - accuracy: 0.4167 - val_loss: 1.1585 - val_accuracy: 0.0000e+00
# Epoch 5/150
# 4/4 [==============================] - 0s 21ms/step - loss: 1.0822 - accuracy: 0.4167 - val_loss: 1.1770 - val_accuracy: 0.0000e+00
# Epoch 6/150
# 4/4 [==============================] - 0s 24ms/step - loss: 1.0733 - accuracy: 0.4167 - val_loss: 1.1954 - val_accuracy: 0.0000e+00
# Epoch 7/150
# 4/4 [==============================] - 0s 23ms/step - loss: 1.0648 - accuracy: 0.4167 - val_loss: 1.2130 - val_accuracy: 0.0000e+00
# Epoch 8/150
# 4/4 [==============================] - 0s 24ms/step - loss: 1.0573 - accuracy: 0.4167 - val_loss: 1.2311 - val_accuracy: 0.0000e+00
# Epoch 9/150
# 4/4 [==============================] - 0s 25ms/step - loss: 1.0501 - accuracy: 0.5667 - val_loss: 1.2495 - val_accuracy: 0.0000e+00
# Epoch 10/150
# 4/4 [==============================] - 0s 23ms/step - loss: 1.0426 - accuracy: 0.7458 - val_loss: 1.2664 - val_accuracy: 0.0000e+00
# Epoch 11/150
# 4/4 [==============================] - 0s 24ms/step - loss: 1.0360 - accuracy: 0.7250 - val_loss: 1.2831 - val_accuracy: 0.0000e+00
# Epoch 12/150
# 4/4 [==============================] - 0s 27ms/step - loss: 1.0297 - accuracy: 0.7167 - val_loss: 1.2993 - val_accuracy: 0.0000e+00
# Epoch 13/150
# 4/4 [==============================] - 0s 24ms/step - loss: 1.0242 - accuracy: 0.7125 - val_loss: 1.3149 - val_accuracy: 0.0000e+00
# Epoch 14/150
# 4/4 [==============================] - 0s 25ms/step - loss: 1.0185 - accuracy: 0.7042 - val_loss: 1.3302 - val_accuracy: 0.0000e+00
# Epoch 15/150
# 4/4 [==============================] - 0s 24ms/step - loss: 1.0132 - accuracy: 0.7083 - val_loss: 1.3451 - val_accuracy: 0.0000e+00
# Epoch 16/150
# 4/4 [==============================] - 0s 25ms/step - loss: 1.0080 - accuracy: 0.7125 - val_loss: 1.3597 - val_accuracy: 0.0000e+00
# Epoch 17/150
# 4/4 [==============================] - 0s 28ms/step - loss: 1.0027 - accuracy: 0.7042 - val_loss: 1.3739 - val_accuracy: 0.0000e+00
# Epoch 18/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.9978 - accuracy: 0.7125 - val_loss: 1.3884 - val_accuracy: 0.0000e+00
# Epoch 19/150
# 4/4 [==============================] - 0s 24ms/step - loss: 0.9928 - accuracy: 0.7167 - val_loss: 1.4027 - val_accuracy: 0.0000e+00
# Epoch 20/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.9879 - accuracy: 0.7167 - val_loss: 1.4169 - val_accuracy: 0.0000e+00
# Epoch 21/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.9829 - accuracy: 0.7208 - val_loss: 1.4305 - val_accuracy: 0.0000e+00
# Epoch 22/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.9785 - accuracy: 0.7208 - val_loss: 1.4451 - val_accuracy: 0.0000e+00
# Epoch 23/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.9735 - accuracy: 0.7208 - val_loss: 1.4588 - val_accuracy: 0.0000e+00
# Epoch 24/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.9687 - accuracy: 0.7208 - val_loss: 1.4725 - val_accuracy: 0.0000e+00
# Epoch 25/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.9642 - accuracy: 0.7208 - val_loss: 1.4871 - val_accuracy: 0.0000e+00
# Epoch 26/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.9593 - accuracy: 0.7208 - val_loss: 1.5007 - val_accuracy: 0.0000e+00
# Epoch 27/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.9550 - accuracy: 0.7208 - val_loss: 1.5146 - val_accuracy: 0.0000e+00
# Epoch 28/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.9503 - accuracy: 0.7208 - val_loss: 1.5278 - val_accuracy: 0.0000e+00
# Epoch 29/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.9459 - accuracy: 0.7167 - val_loss: 1.5407 - val_accuracy: 0.0000e+00
# Epoch 30/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.9416 - accuracy: 0.7208 - val_loss: 1.5534 - val_accuracy: 0.0000e+00
# Epoch 31/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.9373 - accuracy: 0.7208 - val_loss: 1.5658 - val_accuracy: 0.0000e+00
# Epoch 32/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.9331 - accuracy: 0.7208 - val_loss: 1.5783 - val_accuracy: 0.0000e+00
# Epoch 33/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.9287 - accuracy: 0.7167 - val_loss: 1.5907 - val_accuracy: 0.0000e+00
# Epoch 34/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.9246 - accuracy: 0.7167 - val_loss: 1.6036 - val_accuracy: 0.0000e+00
# Epoch 35/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.9200 - accuracy: 0.7167 - val_loss: 1.6157 - val_accuracy: 0.0000e+00
# Epoch 36/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.9157 - accuracy: 0.7167 - val_loss: 1.6284 - val_accuracy: 0.0000e+00
# Epoch 37/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.9114 - accuracy: 0.7083 - val_loss: 1.6408 - val_accuracy: 0.0000e+00
# Epoch 38/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.9069 - accuracy: 0.7083 - val_loss: 1.6527 - val_accuracy: 0.0000e+00
# Epoch 39/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.9028 - accuracy: 0.7125 - val_loss: 1.6652 - val_accuracy: 0.0000e+00
# Epoch 40/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.8984 - accuracy: 0.7125 - val_loss: 1.6770 - val_accuracy: 0.0000e+00
# Epoch 41/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.8941 - accuracy: 0.7125 - val_loss: 1.6885 - val_accuracy: 0.0000e+00
# Epoch 42/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.8897 - accuracy: 0.7125 - val_loss: 1.7000 - val_accuracy: 0.0000e+00
# Epoch 43/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.8854 - accuracy: 0.7125 - val_loss: 1.7119 - val_accuracy: 0.0000e+00
# Epoch 44/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.8812 - accuracy: 0.7125 - val_loss: 1.7243 - val_accuracy: 0.0000e+00
# Epoch 45/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.8768 - accuracy: 0.7125 - val_loss: 1.7365 - val_accuracy: 0.0000e+00
# Epoch 46/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.8724 - accuracy: 0.7125 - val_loss: 1.7488 - val_accuracy: 0.0000e+00
# Epoch 47/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.8680 - accuracy: 0.7125 - val_loss: 1.7609 - val_accuracy: 0.0000e+00
# Epoch 48/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.8636 - accuracy: 0.7125 - val_loss: 1.7732 - val_accuracy: 0.0000e+00
# Epoch 49/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.8592 - accuracy: 0.7125 - val_loss: 1.7863 - val_accuracy: 0.0000e+00
# Epoch 50/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.8546 - accuracy: 0.7125 - val_loss: 1.7982 - val_accuracy: 0.0000e+00
# Epoch 51/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.8500 - accuracy: 0.7083 - val_loss: 1.8102 - val_accuracy: 0.0000e+00
# Epoch 52/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.8455 - accuracy: 0.7083 - val_loss: 1.8232 - val_accuracy: 0.0000e+00
# Epoch 53/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.8410 - accuracy: 0.7083 - val_loss: 1.8365 - val_accuracy: 0.0000e+00
# Epoch 54/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.8362 - accuracy: 0.7083 - val_loss: 1.8485 - val_accuracy: 0.0000e+00
# Epoch 55/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.8315 - accuracy: 0.7125 - val_loss: 1.8612 - val_accuracy: 0.0000e+00
# Epoch 56/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.8269 - accuracy: 0.7083 - val_loss: 1.8744 - val_accuracy: 0.0000e+00
# Epoch 57/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.8221 - accuracy: 0.7125 - val_loss: 1.8876 - val_accuracy: 0.0000e+00
# Epoch 58/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.8173 - accuracy: 0.7125 - val_loss: 1.9006 - val_accuracy: 0.0000e+00
# Epoch 59/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.8125 - accuracy: 0.7125 - val_loss: 1.9140 - val_accuracy: 0.0000e+00
# Epoch 60/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.8077 - accuracy: 0.7125 - val_loss: 1.9272 - val_accuracy: 0.0000e+00
# Epoch 61/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.8026 - accuracy: 0.7125 - val_loss: 1.9395 - val_accuracy: 0.0000e+00
# Epoch 62/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.7980 - accuracy: 0.7125 - val_loss: 1.9529 - val_accuracy: 0.0000e+00
# Epoch 63/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.7929 - accuracy: 0.7125 - val_loss: 1.9653 - val_accuracy: 0.0000e+00
# Epoch 64/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.7882 - accuracy: 0.7125 - val_loss: 1.9794 - val_accuracy: 0.0000e+00
# Epoch 65/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.7833 - accuracy: 0.7125 - val_loss: 1.9931 - val_accuracy: 0.0000e+00
# Epoch 66/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.7786 - accuracy: 0.7083 - val_loss: 2.0059 - val_accuracy: 0.0000e+00
# Epoch 67/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.7737 - accuracy: 0.7083 - val_loss: 2.0204 - val_accuracy: 0.0000e+00
# Epoch 68/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.7688 - accuracy: 0.7125 - val_loss: 2.0345 - val_accuracy: 0.0000e+00
# Epoch 69/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.7642 - accuracy: 0.7125 - val_loss: 2.0495 - val_accuracy: 0.0000e+00
# Epoch 70/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.7593 - accuracy: 0.7167 - val_loss: 2.0647 - val_accuracy: 0.0000e+00
# Epoch 71/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.7546 - accuracy: 0.7250 - val_loss: 2.0791 - val_accuracy: 0.0000e+00
# Epoch 72/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.7501 - accuracy: 0.7250 - val_loss: 2.0952 - val_accuracy: 0.0000e+00
# Epoch 73/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.7452 - accuracy: 0.7250 - val_loss: 2.1085 - val_accuracy: 0.0000e+00
# Epoch 74/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.7407 - accuracy: 0.7250 - val_loss: 2.1232 - val_accuracy: 0.0000e+00
# Epoch 75/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.7360 - accuracy: 0.7292 - val_loss: 2.1374 - val_accuracy: 0.0000e+00
# Epoch 76/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.7314 - accuracy: 0.7292 - val_loss: 2.1524 - val_accuracy: 0.0000e+00
# Epoch 77/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.7271 - accuracy: 0.7292 - val_loss: 2.1680 - val_accuracy: 0.0000e+00
# Epoch 78/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.7225 - accuracy: 0.7292 - val_loss: 2.1826 - val_accuracy: 0.0000e+00
# Epoch 79/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.7182 - accuracy: 0.7333 - val_loss: 2.1968 - val_accuracy: 0.0000e+00
# Epoch 80/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.7137 - accuracy: 0.7333 - val_loss: 2.2114 - val_accuracy: 0.0000e+00
# Epoch 81/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.7095 - accuracy: 0.7333 - val_loss: 2.2270 - val_accuracy: 0.0000e+00
# Epoch 82/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.7051 - accuracy: 0.7375 - val_loss: 2.2419 - val_accuracy: 0.0000e+00
# Epoch 83/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.7010 - accuracy: 0.7375 - val_loss: 2.2562 - val_accuracy: 0.0000e+00
# Epoch 84/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.6968 - accuracy: 0.7375 - val_loss: 2.2725 - val_accuracy: 0.0000e+00
# Epoch 85/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.6927 - accuracy: 0.7375 - val_loss: 2.2874 - val_accuracy: 0.0000e+00
# Epoch 86/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6886 - accuracy: 0.7375 - val_loss: 2.3032 - val_accuracy: 0.0000e+00
# Epoch 87/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6847 - accuracy: 0.7375 - val_loss: 2.3208 - val_accuracy: 0.0000e+00
# Epoch 88/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6807 - accuracy: 0.7333 - val_loss: 2.3364 - val_accuracy: 0.0000e+00
# Epoch 89/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6767 - accuracy: 0.7333 - val_loss: 2.3525 - val_accuracy: 0.0000e+00
# Epoch 90/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6728 - accuracy: 0.7333 - val_loss: 2.3693 - val_accuracy: 0.0000e+00
# Epoch 91/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6691 - accuracy: 0.7375 - val_loss: 2.3857 - val_accuracy: 0.0000e+00
# Epoch 92/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6657 - accuracy: 0.7375 - val_loss: 2.4031 - val_accuracy: 0.0000e+00
# Epoch 93/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6619 - accuracy: 0.7375 - val_loss: 2.4187 - val_accuracy: 0.0000e+00
# Epoch 94/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6584 - accuracy: 0.7333 - val_loss: 2.4342 - val_accuracy: 0.0000e+00
# Epoch 95/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6549 - accuracy: 0.7333 - val_loss: 2.4510 - val_accuracy: 0.0000e+00
# Epoch 96/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6516 - accuracy: 0.7333 - val_loss: 2.4673 - val_accuracy: 0.0000e+00
# Epoch 97/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6483 - accuracy: 0.7375 - val_loss: 2.4844 - val_accuracy: 0.0000e+00
# Epoch 98/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6450 - accuracy: 0.7375 - val_loss: 2.5015 - val_accuracy: 0.0000e+00
# Epoch 99/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.6418 - accuracy: 0.7375 - val_loss: 2.5181 - val_accuracy: 0.0000e+00
# Epoch 100/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.6388 - accuracy: 0.7375 - val_loss: 2.5348 - val_accuracy: 0.0000e+00
# Epoch 101/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6357 - accuracy: 0.7375 - val_loss: 2.5497 - val_accuracy: 0.0000e+00
# Epoch 102/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6326 - accuracy: 0.7375 - val_loss: 2.5644 - val_accuracy: 0.0000e+00
# Epoch 103/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6297 - accuracy: 0.7333 - val_loss: 2.5793 - val_accuracy: 0.0000e+00
# Epoch 104/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6268 - accuracy: 0.7333 - val_loss: 2.5948 - val_accuracy: 0.0000e+00
# Epoch 105/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6239 - accuracy: 0.7375 - val_loss: 2.6110 - val_accuracy: 0.0000e+00
# Epoch 106/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6211 - accuracy: 0.7333 - val_loss: 2.6275 - val_accuracy: 0.0000e+00
# Epoch 107/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6184 - accuracy: 0.7333 - val_loss: 2.6460 - val_accuracy: 0.0000e+00
# Epoch 108/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6157 - accuracy: 0.7333 - val_loss: 2.6631 - val_accuracy: 0.0000e+00
# Epoch 109/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.6130 - accuracy: 0.7375 - val_loss: 2.6797 - val_accuracy: 0.0000e+00
# Epoch 110/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.6106 - accuracy: 0.7375 - val_loss: 2.6959 - val_accuracy: 0.0000e+00
# Epoch 111/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6080 - accuracy: 0.7375 - val_loss: 2.7108 - val_accuracy: 0.0000e+00
# Epoch 112/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6054 - accuracy: 0.7375 - val_loss: 2.7248 - val_accuracy: 0.0000e+00
# Epoch 113/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6029 - accuracy: 0.7375 - val_loss: 2.7377 - val_accuracy: 0.0000e+00
# Epoch 114/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6005 - accuracy: 0.7375 - val_loss: 2.7521 - val_accuracy: 0.0000e+00
# Epoch 115/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5983 - accuracy: 0.7375 - val_loss: 2.7654 - val_accuracy: 0.0000e+00
# Epoch 116/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5958 - accuracy: 0.7375 - val_loss: 2.7796 - val_accuracy: 0.0000e+00
# Epoch 117/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5936 - accuracy: 0.7375 - val_loss: 2.7948 - val_accuracy: 0.0000e+00
# Epoch 118/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5913 - accuracy: 0.7375 - val_loss: 2.8121 - val_accuracy: 0.0000e+00
# Epoch 119/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5893 - accuracy: 0.7375 - val_loss: 2.8293 - val_accuracy: 0.0000e+00
# Epoch 120/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5869 - accuracy: 0.7375 - val_loss: 2.8435 - val_accuracy: 0.0000e+00
# Epoch 121/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5849 - accuracy: 0.7375 - val_loss: 2.8580 - val_accuracy: 0.0000e+00
# Epoch 122/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5828 - accuracy: 0.7375 - val_loss: 2.8748 - val_accuracy: 0.0000e+00
# Epoch 123/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5808 - accuracy: 0.7375 - val_loss: 2.8905 - val_accuracy: 0.0000e+00
# Epoch 124/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5787 - accuracy: 0.7375 - val_loss: 2.9048 - val_accuracy: 0.0000e+00
# Epoch 125/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5767 - accuracy: 0.7375 - val_loss: 2.9200 - val_accuracy: 0.0000e+00
# Epoch 126/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5748 - accuracy: 0.7375 - val_loss: 2.9341 - val_accuracy: 0.0000e+00
# Epoch 127/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5728 - accuracy: 0.7375 - val_loss: 2.9500 - val_accuracy: 0.0000e+00
# Epoch 128/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5709 - accuracy: 0.7375 - val_loss: 2.9636 - val_accuracy: 0.0000e+00
# Epoch 129/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5692 - accuracy: 0.7375 - val_loss: 2.9797 - val_accuracy: 0.0000e+00
# Epoch 130/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5672 - accuracy: 0.7375 - val_loss: 2.9924 - val_accuracy: 0.0000e+00
# Epoch 131/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5654 - accuracy: 0.7375 - val_loss: 3.0066 - val_accuracy: 0.0000e+00
# Epoch 132/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5636 - accuracy: 0.7375 - val_loss: 3.0203 - val_accuracy: 0.0000e+00
# Epoch 133/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5619 - accuracy: 0.7375 - val_loss: 3.0333 - val_accuracy: 0.0000e+00
# Epoch 134/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5601 - accuracy: 0.7375 - val_loss: 3.0500 - val_accuracy: 0.0000e+00
# Epoch 135/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5584 - accuracy: 0.7375 - val_loss: 3.0649 - val_accuracy: 0.0000e+00
# Epoch 136/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5566 - accuracy: 0.7417 - val_loss: 3.0788 - val_accuracy: 0.0000e+00
# Epoch 137/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5549 - accuracy: 0.7417 - val_loss: 3.0946 - val_accuracy: 0.0000e+00
# Epoch 138/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5533 - accuracy: 0.7375 - val_loss: 3.1088 - val_accuracy: 0.0000e+00
# Epoch 139/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5517 - accuracy: 0.7375 - val_loss: 3.1227 - val_accuracy: 0.0000e+00
# Epoch 140/150
# 4/4 [==============================] - 0s 29ms/step - loss: 0.5501 - accuracy: 0.7417 - val_loss: 3.1377 - val_accuracy: 0.0000e+00
# Epoch 141/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.5484 - accuracy: 0.7417 - val_loss: 3.1505 - val_accuracy: 0.0000e+00
# Epoch 142/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.5469 - accuracy: 0.7417 - val_loss: 3.1635 - val_accuracy: 0.0000e+00
# Epoch 143/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5453 - accuracy: 0.7417 - val_loss: 3.1769 - val_accuracy: 0.0000e+00
# Epoch 144/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5437 - accuracy: 0.7417 - val_loss: 3.1880 - val_accuracy: 0.0000e+00
# Epoch 145/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5421 - accuracy: 0.7417 - val_loss: 3.2023 - val_accuracy: 0.0000e+00
# Epoch 146/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5407 - accuracy: 0.7458 - val_loss: 3.2166 - val_accuracy: 0.0000e+00
# Epoch 147/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5390 - accuracy: 0.7500 - val_loss: 3.2305 - val_accuracy: 0.0000e+00
# Epoch 148/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.5376 - accuracy: 0.7458 - val_loss: 3.2434 - val_accuracy: 0.0000e+00
# Epoch 149/150
# 4/4 [==============================] - 0s 28ms/step - loss: 0.5361 - accuracy: 0.7500 - val_loss: 3.2579 - val_accuracy: 0.0000e+00
# Epoch 150/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.5346 - accuracy: 0.7500 - val_loss: 3.2751 - val_accuracy: 0.0000e+00

# %%
plt.plot(history.history['accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %% [markdown]
# # Создание многослойной нейросети для классификации рукописных цифр

# %%
import keras

from keras.datasets import mnist
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.models import Sequential
from keras.optimizers import adam_v2
from keras.utils import np_utils
from keras.utils import np_utils

import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

number_of_classes = 10

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

plt.figure()
plt.imshow(X_train[0])
plt.colorbar()
plt.grid(False)

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i], cmap=plt.cm.binary)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1]*X_train.shape[2]).astype('float32')
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1]*X_test.shape[2]).astype('float32')

#для преобразования двумерных данных в одномерные в нейронной сети можно использовать слой Flatten(input_shape=(28,28))

X_train/=255
X_test/=255

y_train = np_utils.to_categorical(y_train, number_of_classes)
y_test = np_utils.to_categorical(y_test, number_of_classes)

# %%
X_train.shape
# Out:
# (60000, 784)

# %%
model = keras.models.Sequential()
model.add(keras.layers.Dense(512, input_dim=(X_train.shape[1]), activation='relu'))
model.add(keras.layers.Dense(number_of_classes, activation='softmax'))
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 512)               401920
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history=model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5, batch_size=200)
# Out:
# Epoch 1/5
# 300/300 [==============================] - 3s 8ms/step - loss: 0.3046 - accuracy: 0.9153 - val_loss: 0.1558 - val_accuracy: 0.9543
# Epoch 2/5
# 300/300 [==============================] - 2s 5ms/step - loss: 0.1257 - accuracy: 0.9640 - val_loss: 0.1052 - val_accuracy: 0.9684
# Epoch 3/5
# 300/300 [==============================] - 2s 5ms/step - loss: 0.0832 - accuracy: 0.9764 - val_loss: 0.0862 - val_accuracy: 0.9746
# Epoch 4/5
# 300/300 [==============================] - 2s 8ms/step - loss: 0.0600 - accuracy: 0.9828 - val_loss: 0.0841 - val_accuracy: 0.9731
# Epoch 5/5
# 300/300 [==============================] - 1s 4ms/step - loss: 0.0459 - accuracy: 0.9872 - val_loss: 0.0737 - val_accuracy: 0.9776

# %%
#оценка точности
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
print('Test loss:', test_loss)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0737 - accuracy: 0.9776
# Test accuracy: 0.9775999784469604
# Test loss: 0.07374592870473862

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax1.plot(history.history['accuracy'])
ax1.plot(history.history['val_accuracy'])
ax1.set(title='model accuracy')
ax1.set(ylabel='accuracy')
ax1.set(xlabel='epoch')
ax1.legend(['train', 'test'], loc='upper left')
ax2 = fig.add_subplot(1,2,2)
ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set(title='model loss')
ax2.set(ylabel='loss')
ax2.set(xlabel='epoch')
ax2.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Инициализация сети
# Важным моментом при конструировании сети является начальная инициализация весов. Удачно выбранный способ инициализации весов может значительно влиять на способность модели к обучению.
#
# Существует различные подходы к начальной инициализации весов.
#
# Например, метод Завьера. Основная идея этого метода — упростить прохождение сигнала через слой во время как прямого, так и обратного распространения ошибки для линейной функции активации (этот метод также хорошо работает для сигмоидной функции, так как участок, где она ненасыщена, также имеет линейный характер). При вычислении весов этот метод опирается на вероятностное распределение.
#
# Метод инициализации Ге (He) — это вариация метода Завьера, больше подходящая функции активации ReLU, компенсирующая тот факт, что эта функция возвращает нуль для половины области определения.
#
# Выделяют также метод ортогональной инициализации.

# %%
model_reg = keras.models.Sequential()
model_reg.add(keras.layers.Dense(512, input_dim=(X_train.shape[1]), activation='relu', kernel_initializer='he_uniform'))
model_reg.add(keras.layers.Dense(number_of_classes, activation='softmax', kernel_initializer='glorot_uniform'))

# %% [markdown]
# # L2-регуляризация
# Одной из основных проблем машинного обучения является проблема переобучения (overfitting), когда модель в погоне за минимизацией затрат на обучение теряет способность к обобщению.
#
# Существует простой способ держать переобучение под контролем — метод dropout.
#
# Но есть и другие регуляризаторы, которые можно применить к сети. Один из них — L_2-регуляризация (также называемая сокращением весов, англ. weight decay), которая использует более прямой подход к регуляризации, чем dropout. Обычно первопричиной переобучения является сложность модели (в смысле количества ее параметров), слишком высокая для решаемой задачи и имеющегося обучающего множества. В некотором смысле, задача регуляризатора — понизить сложность модели, сохранив количество ее параметров.
#
# L_2-регуляризация выполняется посредством наложения штрафов (penalising) на веса с наибольшими значениями, минимизируя их L_2-норму с использованием параметра λ — коэффициент регуляризации, выражающий предпочтение минимизации нормы относительно минимизации потерь на обучающем множестве.
#
# Крайне важно правильно выбрать λ. Если коэффициент слишком мал, то эффект от регуляризации будет ничтожен, если же слишком велик — модель обнулит все веса.

# %%
from keras.regularizers import l2
l2_lambda = 0.0001
model_reg = keras.models.Sequential()
model_reg.add(keras.layers.Dense(512, input_dim=(X_train.shape[1]), activation='relu',kernel_initializer='he_uniform', bias_regularizer=l2(l2_lambda)))
model_reg.add(keras.layers.Dense(number_of_classes, activation='softmax', kernel_initializer='glorot_uniform'))

# %%
model_reg.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history=model_reg.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5, batch_size=200)
# Out:
# Epoch 1/5
# 300/300 [==============================] - 2s 5ms/step - loss: 0.3011 - accuracy: 0.9140 - val_loss: 0.1499 - val_accuracy: 0.9582
# Epoch 2/5
# 300/300 [==============================] - 1s 4ms/step - loss: 0.1228 - accuracy: 0.9651 - val_loss: 0.1044 - val_accuracy: 0.9692
# Epoch 3/5
# 300/300 [==============================] - 1s 4ms/step - loss: 0.0811 - accuracy: 0.9765 - val_loss: 0.0831 - val_accuracy: 0.9755
# Epoch 4/5
# 300/300 [==============================] - 2s 5ms/step - loss: 0.0590 - accuracy: 0.9831 - val_loss: 0.0795 - val_accuracy: 0.9755
# Epoch 5/5
# 300/300 [==============================] - 1s 4ms/step - loss: 0.0439 - accuracy: 0.9872 - val_loss: 0.0708 - val_accuracy: 0.9783

# %% [markdown]
# ## Применение обученной нейронной сети
# Необходимо нарисовать цифру (например в Paint) или скачать из Интернета

# %%
#выполняем преобразование картинки с цифрой
from PIL import Image
#преобразование входного изображения в формат набора MNIS
image=Image.open("cifra-2.png").resize((28,28))
img = np.invert(image.convert('L')).ravel()
im2arr = img.reshape(1, 28* 28).astype('float32')/255
#plt.imshow(image, cmap=plt.cm.binary)
#использование обученной модели
y_pred = model.predict(im2arr)
print(y_pred[0]) 
plt.bar(range(10), y_pred[0])
plt.show()
print(np.argmax(y_pred))
# Out:
# [1.4453518e-11 1.0677580e-11 6.7775865e-04 4.6621627e-01 3.0039981e-24
#  3.2977484e-02 8.3165309e-05 5.0001395e-01 3.1352767e-05 6.3720331e-12]
# 7

# %%
#сохранение модели
model.save('model.h5') 

#загрузка модели
#model_load=keras.models.load_model('model.h5')

# %% [markdown]
# ## Задание 1
#
# Для набора данных "Спираль"
# 1. Попробуйте улучшить результат классификации за счет изменения следующих параметров: скорость обучения, количество эпох, виды оптимизаторов, количество нейронов, количество слоев. Результаты анализа представьте в виде графиков (диаграмм).
# 2. Добавьте слой (слои) Dropout (model.add(keras.layers.Dropout(0.5))), посмотрите, как изменится результат.
# 3. Добавьте слой нормализации (keras.layers.BatchNormalization) и оцените его влияние на качество обучения. Сделайте выводы.

# %% [markdown]
# ## Задание 2
# Для набора данных MNIST
# 1. Между двух слоев нейронной сети добавить слой Dropout
# model.add(keras.layers.Dropout(0.5)), переобучить модель, оценить качество обучения.
# Объяснить полученные результаты
# 2. Добавить еще один скрытый слой и проанализировать его влияние на качество обучения модели.

# %% [markdown]
# ## Задание 3
# 1. Создайте модель нейронной сети для решения задачи классификации из Лабораторной работы №5, в соответствии с вариантом задания
# 1. Обучите модель. В завсимости от результатов, видоизмените модель, чтобы попытаться добиться большей точности
