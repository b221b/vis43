# %% [markdown]
# ---

# %% [markdown]
# <h2 style="text-align: center;"><b>НС из одного нейрона</b></h3>

# %% [markdown]
# ---

# %% [markdown]
# <h3 style="text-align: center;"><b>Компоненты нейросети</b></h3>

# %% [markdown]
# Здесь самое время напомнить о том, какие вещи играют принципиальную роль в построении любой ***нейронной сети*** (все их мы задаём *руками*, самостоятельно):
#
# - непосредственно, сама **архитектура** нейросети (сюда входят типы функций активации у каждого нейрона);
# - начальная **инициализация** весов каждого слоя;
# - метод **оптимизации** нейросети (сюда ещё входит метод изменения `learning_rate`);
# - размер **батчей** (`batch_size`);
# - количество **эпох** обучения (`num_epochs`);
# - **функция потерь** (`loss`);
# - тип **регуляризации** нейросети (для каждого слоя можно свой);
#
# То, что связано с ***данными и задачей***:
# - само **качество** выборки (непротиворечивость, чистота, корректность постановки задачи);
# - **размер** выборки;

# %% [markdown]
# ##<h3 style="text-align: center;"><b>Один нейрон на Keras</b></h3>

# %% [markdown]
# Данные пока что возьмём как и прежде -- "яблоки и груши":

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("apples_pears.csv")

# %%
plt.figure(figsize=(10, 8))
plt.scatter(data.iloc[:, 0], data.iloc[:, 1], c=data['target'], cmap='rainbow')
plt.title('Яблоки и груши', fontsize=15)
plt.xlabel('симметричность', fontsize=14)
plt.ylabel('желтизна', fontsize=14)
plt.show();

# %%
X = data.iloc[:,:2].values  # матрица объекты-признаки
y = data['target'].values.reshape((-1, 1))  # классы (столбец из нулей и единиц)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.activations import sigmoid

# %%
X[:,:10]
# Out:
# array([[0.77942731, 0.25730527],
#        [0.77700501, 0.0159154 ],
#        [0.97709225, 0.30420962],
#        ...,
#        [0.92721921, 0.13498618],
#        [0.01582991, 0.48132194],
#        [0.96796389, 0.30857107]])

# %%
num_features = X.shape[1]

neuron = Sequential()
neuron.add(Dense(1, input_shape=(num_features,), activation=sigmoid))

# %%
neuron

# %% [markdown]
# Пока что мы просто создали объект класса `Sequential`, который состоит из одного линейного слоя размерности (num_features, 1) и последующего применения сигмоиды. Но уже сейчас его можно применить к объекту (тензору), просто веса в начале инициализирутся случайно и при forward_pass'е мы получим какой-то ответ пока что необученного нейрона:

# %%
neuron.predict([[1,1]])
# Out:
# array([[0.39249486]], dtype=float32)

# %% [markdown]
# Предскажем ещё необученным нейроном:

# %%
proba_pred = neuron.predict(X)
y_pred = proba_pred > 0.5
print(y_pred[:5])
y_pred = y_pred.reshape(-1)

plt.figure(figsize=(10, 8))
plt.scatter(data.iloc[:, 0], data.iloc[:, 1], c=y_pred, cmap='spring')
plt.title('Яблоки и груши', fontsize=15)
plt.xlabel('симметричность', fontsize=14)
plt.ylabel('желтизна', fontsize=14)
plt.show();
# Out:
# [[False]
#  [ True]
#  [False]
#  [False]
#  [False]]

# %% [markdown]
# Как и ожидалось, ничего полезного. Давайте научим нейрон отличать груши от яблок по их симметричности и желтизне!

# %% [markdown]
# ## Код обучения одного нейрона на Keras:

# %%
import tensorflow as tf
from tensorflow.keras import optimizers
sgd = optimizers.SGD(decay=1e-6, momentum=0.9, nesterov=True, learning_rate=0.01)
neuron.compile(loss='mean_squared_error', optimizer=sgd, metrics=['accuracy'])
history=neuron.fit(X, y, epochs=100, batch_size=25, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 7ms/step - loss: 0.2211 - accuracy: 0.8413 - val_loss: 0.2100 - val_accuracy: 0.8850
# Epoch 2/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2033 - accuracy: 0.8363 - val_loss: 0.1959 - val_accuracy: 0.8000
# Epoch 3/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1921 - accuracy: 0.7862 - val_loss: 0.1862 - val_accuracy: 0.7750
# Epoch 4/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1835 - accuracy: 0.7887 - val_loss: 0.1778 - val_accuracy: 0.8050
# Epoch 5/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1759 - accuracy: 0.8012 - val_loss: 0.1702 - val_accuracy: 0.8300
# Epoch 6/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1689 - accuracy: 0.8213 - val_loss: 0.1633 - val_accuracy: 0.8450
# Epoch 7/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1626 - accuracy: 0.8313 - val_loss: 0.1569 - val_accuracy: 0.8550
# Epoch 8/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1568 - accuracy: 0.8425 - val_loss: 0.1512 - val_accuracy: 0.8600
# Epoch 9/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1515 - accuracy: 0.8550 - val_loss: 0.1459 - val_accuracy: 0.8750
# Epoch 10/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1467 - accuracy: 0.8625 - val_loss: 0.1410 - val_accuracy: 0.8800
# Epoch 11/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1422 - accuracy: 0.8712 - val_loss: 0.1366 - val_accuracy: 0.8800
# Epoch 12/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1381 - accuracy: 0.8775 - val_loss: 0.1324 - val_accuracy: 0.8850
# Epoch 13/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1343 - accuracy: 0.8775 - val_loss: 0.1286 - val_accuracy: 0.8850
# Epoch 14/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1308 - accuracy: 0.8788 - val_loss: 0.1251 - val_accuracy: 0.8850
# Epoch 15/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1276 - accuracy: 0.8888 - val_loss: 0.1218 - val_accuracy: 0.8900
# Epoch 16/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1245 - accuracy: 0.8900 - val_loss: 0.1188 - val_accuracy: 0.8900
# Epoch 17/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1217 - accuracy: 0.8913 - val_loss: 0.1160 - val_accuracy: 0.8950
# Epoch 18/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1191 - accuracy: 0.8950 - val_loss: 0.1133 - val_accuracy: 0.9000
# Epoch 19/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1166 - accuracy: 0.8988 - val_loss: 0.1109 - val_accuracy: 0.9100
# Epoch 20/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1143 - accuracy: 0.8988 - val_loss: 0.1085 - val_accuracy: 0.9100
# Epoch 21/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1121 - accuracy: 0.8988 - val_loss: 0.1063 - val_accuracy: 0.9150
# Epoch 22/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1101 - accuracy: 0.9000 - val_loss: 0.1043 - val_accuracy: 0.9150
# Epoch 23/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1082 - accuracy: 0.9000 - val_loss: 0.1023 - val_accuracy: 0.9150
# Epoch 24/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1064 - accuracy: 0.9000 - val_loss: 0.1005 - val_accuracy: 0.9150
# Epoch 25/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1046 - accuracy: 0.9013 - val_loss: 0.0988 - val_accuracy: 0.9200
# Epoch 26/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1030 - accuracy: 0.9050 - val_loss: 0.0971 - val_accuracy: 0.9200
# Epoch 27/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1015 - accuracy: 0.9075 - val_loss: 0.0955 - val_accuracy: 0.9250
# Epoch 28/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1000 - accuracy: 0.9100 - val_loss: 0.0940 - val_accuracy: 0.9250
# Epoch 29/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0986 - accuracy: 0.9100 - val_loss: 0.0926 - val_accuracy: 0.9300
# Epoch 30/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0972 - accuracy: 0.9112 - val_loss: 0.0913 - val_accuracy: 0.9350
# Epoch 31/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0960 - accuracy: 0.9112 - val_loss: 0.0900 - val_accuracy: 0.9350
# Epoch 32/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0947 - accuracy: 0.9112 - val_loss: 0.0887 - val_accuracy: 0.9350
# Epoch 33/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0936 - accuracy: 0.9125 - val_loss: 0.0875 - val_accuracy: 0.9350
# Epoch 34/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0925 - accuracy: 0.9137 - val_loss: 0.0864 - val_accuracy: 0.9450
# Epoch 35/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0914 - accuracy: 0.9137 - val_loss: 0.0853 - val_accuracy: 0.9400
# Epoch 36/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0904 - accuracy: 0.9137 - val_loss: 0.0842 - val_accuracy: 0.9450
# Epoch 37/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0893 - accuracy: 0.9150 - val_loss: 0.0832 - val_accuracy: 0.9450
# Epoch 38/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0884 - accuracy: 0.9200 - val_loss: 0.0823 - val_accuracy: 0.9500
# Epoch 39/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0875 - accuracy: 0.9225 - val_loss: 0.0813 - val_accuracy: 0.9500
# Epoch 40/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0866 - accuracy: 0.9175 - val_loss: 0.0804 - val_accuracy: 0.9500
# Epoch 41/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0858 - accuracy: 0.9187 - val_loss: 0.0795 - val_accuracy: 0.9500
# Epoch 42/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0849 - accuracy: 0.9237 - val_loss: 0.0787 - val_accuracy: 0.9500
# Epoch 43/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0841 - accuracy: 0.9225 - val_loss: 0.0779 - val_accuracy: 0.9500
# Epoch 44/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0834 - accuracy: 0.9237 - val_loss: 0.0771 - val_accuracy: 0.9500
# Epoch 45/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0826 - accuracy: 0.9250 - val_loss: 0.0763 - val_accuracy: 0.9500
# Epoch 46/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0819 - accuracy: 0.9250 - val_loss: 0.0756 - val_accuracy: 0.9500
# Epoch 47/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0812 - accuracy: 0.9250 - val_loss: 0.0749 - val_accuracy: 0.9500
# Epoch 48/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0805 - accuracy: 0.9250 - val_loss: 0.0742 - val_accuracy: 0.9500
# Epoch 49/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0799 - accuracy: 0.9275 - val_loss: 0.0735 - val_accuracy: 0.9500
# Epoch 50/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0793 - accuracy: 0.9275 - val_loss: 0.0729 - val_accuracy: 0.9500
# Epoch 51/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0786 - accuracy: 0.9275 - val_loss: 0.0722 - val_accuracy: 0.9500
# Epoch 52/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0780 - accuracy: 0.9275 - val_loss: 0.0716 - val_accuracy: 0.9500
# Epoch 53/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0774 - accuracy: 0.9275 - val_loss: 0.0710 - val_accuracy: 0.9500
# Epoch 54/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0769 - accuracy: 0.9300 - val_loss: 0.0704 - val_accuracy: 0.9500
# Epoch 55/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0763 - accuracy: 0.9300 - val_loss: 0.0698 - val_accuracy: 0.9500
# Epoch 56/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0758 - accuracy: 0.9300 - val_loss: 0.0693 - val_accuracy: 0.9500
# Epoch 57/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0753 - accuracy: 0.9300 - val_loss: 0.0688 - val_accuracy: 0.9500
# Epoch 58/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0747 - accuracy: 0.9300 - val_loss: 0.0682 - val_accuracy: 0.9500
# Epoch 59/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0742 - accuracy: 0.9300 - val_loss: 0.0677 - val_accuracy: 0.9500
# Epoch 60/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0737 - accuracy: 0.9300 - val_loss: 0.0672 - val_accuracy: 0.9500
# Epoch 61/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0733 - accuracy: 0.9300 - val_loss: 0.0667 - val_accuracy: 0.9500
# Epoch 62/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0728 - accuracy: 0.9300 - val_loss: 0.0662 - val_accuracy: 0.9500
# Epoch 63/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0723 - accuracy: 0.9312 - val_loss: 0.0658 - val_accuracy: 0.9500
# Epoch 64/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0719 - accuracy: 0.9312 - val_loss: 0.0654 - val_accuracy: 0.9500
# Epoch 65/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0715 - accuracy: 0.9312 - val_loss: 0.0649 - val_accuracy: 0.9500
# Epoch 66/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0711 - accuracy: 0.9312 - val_loss: 0.0645 - val_accuracy: 0.9500
# Epoch 67/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0707 - accuracy: 0.9312 - val_loss: 0.0641 - val_accuracy: 0.9500
# Epoch 68/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0703 - accuracy: 0.9312 - val_loss: 0.0636 - val_accuracy: 0.9500
# Epoch 69/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0699 - accuracy: 0.9312 - val_loss: 0.0632 - val_accuracy: 0.9500
# Epoch 70/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0695 - accuracy: 0.9325 - val_loss: 0.0628 - val_accuracy: 0.9500
# Epoch 71/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0691 - accuracy: 0.9325 - val_loss: 0.0624 - val_accuracy: 0.9500
# Epoch 72/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0687 - accuracy: 0.9337 - val_loss: 0.0621 - val_accuracy: 0.9500
# Epoch 73/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0684 - accuracy: 0.9337 - val_loss: 0.0617 - val_accuracy: 0.9500
# Epoch 74/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0680 - accuracy: 0.9337 - val_loss: 0.0613 - val_accuracy: 0.9500
# Epoch 75/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0677 - accuracy: 0.9337 - val_loss: 0.0610 - val_accuracy: 0.9500
# Epoch 76/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0673 - accuracy: 0.9350 - val_loss: 0.0606 - val_accuracy: 0.9500
# Epoch 77/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0670 - accuracy: 0.9350 - val_loss: 0.0603 - val_accuracy: 0.9500
# Epoch 78/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0667 - accuracy: 0.9350 - val_loss: 0.0599 - val_accuracy: 0.9500
# Epoch 79/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0663 - accuracy: 0.9362 - val_loss: 0.0596 - val_accuracy: 0.9500
# Epoch 80/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0661 - accuracy: 0.9362 - val_loss: 0.0593 - val_accuracy: 0.9500
# Epoch 81/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0657 - accuracy: 0.9362 - val_loss: 0.0590 - val_accuracy: 0.9500
# Epoch 82/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9362 - val_loss: 0.0587 - val_accuracy: 0.9500
# Epoch 83/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0651 - accuracy: 0.9362 - val_loss: 0.0583 - val_accuracy: 0.9500
# Epoch 84/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0648 - accuracy: 0.9362 - val_loss: 0.0580 - val_accuracy: 0.9500
# Epoch 85/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0646 - accuracy: 0.9375 - val_loss: 0.0578 - val_accuracy: 0.9500
# Epoch 86/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0642 - accuracy: 0.9375 - val_loss: 0.0574 - val_accuracy: 0.9500
# Epoch 87/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0640 - accuracy: 0.9375 - val_loss: 0.0571 - val_accuracy: 0.9500
# Epoch 88/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0637 - accuracy: 0.9375 - val_loss: 0.0569 - val_accuracy: 0.9500
# Epoch 89/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0634 - accuracy: 0.9375 - val_loss: 0.0566 - val_accuracy: 0.9500
# Epoch 90/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0632 - accuracy: 0.9375 - val_loss: 0.0563 - val_accuracy: 0.9500
# Epoch 91/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0629 - accuracy: 0.9375 - val_loss: 0.0560 - val_accuracy: 0.9500
# Epoch 92/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0627 - accuracy: 0.9375 - val_loss: 0.0558 - val_accuracy: 0.9500
# Epoch 93/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0624 - accuracy: 0.9388 - val_loss: 0.0555 - val_accuracy: 0.9500
# Epoch 94/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0622 - accuracy: 0.9388 - val_loss: 0.0553 - val_accuracy: 0.9500
# Epoch 95/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0619 - accuracy: 0.9388 - val_loss: 0.0550 - val_accuracy: 0.9500
# Epoch 96/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0617 - accuracy: 0.9388 - val_loss: 0.0548 - val_accuracy: 0.9500
# Epoch 97/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0614 - accuracy: 0.9400 - val_loss: 0.0545 - val_accuracy: 0.9500
# Epoch 98/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0612 - accuracy: 0.9400 - val_loss: 0.0543 - val_accuracy: 0.9500
# Epoch 99/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0610 - accuracy: 0.9400 - val_loss: 0.0541 - val_accuracy: 0.9500
# Epoch 100/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0607 - accuracy: 0.9400 - val_loss: 0.0538 - val_accuracy: 0.9500

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
#plt.legend(['train','test'])
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
#plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# Обучили. Предскажем теперь:

# %%
proba_pred = neuron.predict(X)
y_pred = proba_pred > 0.5
y_pred = y_pred.reshape(-1)

plt.figure(figsize=(10, 8))
plt.scatter(data.iloc[:, 0], data.iloc[:, 1], c=y_pred, cmap='spring')
plt.title('Яблоки и груши', fontsize=15)
plt.xlabel('симметричность', fontsize=14)
plt.ylabel('желтизна', fontsize=14)
plt.show();

# %% [markdown]
# #<h2 style="text-align: center;"><b>Многослойная сеть на Keras</b></h3>

# %% [markdown]
# ---

# %% [markdown]
# ##<h3 style="text-align: center;"><b>Компоненты нейросети</b></h3>

# %% [markdown]
# Здесь самое время напомнить о том, какие вещи играют принципиальную роль в построении любой ***нейронной сети*** (все их мы задаём *руками*, самостоятельно):
#
# - непосредственно, сама **архитектура** нейросети (сюда входят типы функций активации у каждого нейрона);
# - начальная **инициализация** весов каждого слоя;
# - метод **оптимизации** нейросети (сюда ещё входит метод изменения `learning_rate`);
# - размер **батчей** (`batch_size`);
# - количество итераций обучения (`num_epochs`);
# - **функция потерь** (`loss`);
# - тип **регуляризации** нейросети (для каждого слоя можно свой);
#
# То, что связано с ***данными и задачей***:
# - само **качество** выборки (непротиворечивость, чистота, корректность постановки задачи);
# - **размер** выборки;

# %% [markdown]
# ## Многослойная нейронная сеть

# %% [markdown]
# Как можно понять из названия, многослойная нейросеть состоит из нескольких **слоёв**. Каждый слой состоит из **нейронов**. Ранее мы уже писали свой нейрон на NumPy, вот из таких нейронов и состоит ***MLP (Multi-Layer Perceptron)***. Ещё такую многослойную нейросеть, у которой каждый нейрон на предыдущем уровне соединён с нейроном на следующем уровне, называют ***Fully-Connected-сетью*** (или ***Dense-сетью***).
#
# Расмотрим их устройство более подробно:

# %% [markdown]
# * Вот так выглядит двухслойная нейросеть (первый слой - input layer - не считается, потому что это, по сути, не слой):

# %% [markdown]
# <img src="http://cs231n.github.io/assets/nn1/neural_net.jpeg" width=300, height=200>

# %% [markdown]
# * Так выглядит трёхслойная нейросеть:

# %% [markdown]
# <img src="http://cs231n.github.io/assets/nn1/neural_net2.jpeg" width=400, height=300>

# %% [markdown]
# .. и так далее для большего случая слоёв.

# %% [markdown]
# **Обратите внимание:** связи есть у нейронов со слоя $L_{i-1}$  и нейронов $L_{i}$, но между нейронами в одном слое связей **нет**.

# %% [markdown]
# **Входной слой** -- это данные (матрица $(n, m)$).

# %% [markdown]
# Слои, которые не являются входными или выходными, называются **скрытыми слоями (hidden layers)**.

# %% [markdown]
# При решении ***задачи регрессии*** на **выходном слое** обычно один нейрон, который возвращает предсказанные числа (для каждого объекта по числу).
#
# В случае ***задачи классификации*** на **выходном слое** обычно один нейрон, если задача бинарной классификации, и $K$ нейронов, если задача $K$-класовой классификации.

# %% [markdown]
# #### Forward pass в MLP

# %% [markdown]
# Каждый слой многослойной нейросети - это матрица весов, столбцы которой -- это нейроны (один столбец - один нейрон). То есть один столбец -- это веса одного нейрона.

# %% [markdown]
# Допустим, мы решаем задачу $K$-классовой классификации (на последнем слое $K$ нейронов). Рассмотрим, как в таком случае выглядит `forward_pass` нейросети:

# %% [markdown]
# * Вход: $$X =
# \left(
# \begin{matrix}
# x_{11} & ... & x_{1M} \\
# ... & \ddots  & ...\\
# x_{N1} & ... & x_{NM}
# \end{matrix}
# \right)
# $$
#
# -- матрица $(N, M)$

# %% [markdown]
# * Структура сети - много слоёв, в слоях много нейронов. Первый слой (после входного) выглядит так:

# %% [markdown]
# $$ W^1 =
# \left(
# \begin{matrix}
# w_{11} & ... & w_{1L_1} \\
# ... & \ddots  & ...\\
# w_{M1} & ... & w_{ML_1}
# \end{matrix}
# \right)
# $$
#
# -- матрица $(M, L_1)$

# %% [markdown]
# То есть это в точности $L_1$ нейронов, каждый имеет свои собственные веса, их $M$ штук.

# %% [markdown]
# Мы помним, что нейрон - это линейное преобразование и потом нелинейная функция активации от этого преобразования. Однако в многослойных нейростеях часто отделяют `Linear` часть и `Activation`, то есть слоем считаем набор весов нейронов, а следующий слой всегда функция активации (у всех нейронов из слоя она одна и та же, обычно фреймворки не позволяют задавать конкретному нейрону в слое отличную от других нейронов в этом слое функцию активации, однако это легко сделать, объявив слой из одного нейрона).

# %% [markdown]
# * Другие слои выглядит точно так же, как первый слой. Например, второй слой будет такой:

# %% [markdown]
# $$ W^2 =
# \left(
# \begin{matrix}
# w_{11} & ... & w_{1L_2} \\
# ... & \ddots  & ...\\
# w_{L_11} & ... & w_{L_1L_2}
# \end{matrix}
# \right)
# $$
#
# -- матрица $(L_1, L_2)$

# %% [markdown]
# То есть это в точности $L_2$ нейронов, каждый имеет свои собственные веса, их $L_1$ штук.

# %% [markdown]
# * Выходной слой:
#
# Пусть в нейросети до выходного слоя идут $t$ слоёв. Тогда выходной слой имеет форму:

# %% [markdown]
# $$ W^{out} =
# \left(
# \begin{matrix}
# w_{11} & ... & w_{1K} \\
# ... & \ddots  & ...\\
# w_{L_t1} & ... & w_{L_tK}
# \end{matrix}
# \right)
# $$
#
# -- матрица $(L_t, K)$, где $L_t$ - количество нейронов в $t$-ом слое, а $K$ -- количество классов.

# %% [markdown]
# В итоге *для `forward_pass` нам нужно просто последовтельно перемножить матрицы друг за другом, применяя после каждого умножения соответсвующую функцию активации*.

# %% [markdown]
# *Примечание*: можно думать об умножении на очередную матрицу весов как на переход в **новое признаковое пространство**. Действительно, когда подаём матрицу $X$ и умножаем на матрицу первого слоя, мы получаем матрицу размера $(N, L_1)$, то есть как будто $L_1$ "новых" признаков (построенных как линейная комбинация старых до применения функции активации, и уже как нелинейная комбинация после активации). Здесь уместно вспомнить, что Deep Learning является пообластью Representation Learning, то есть позволяет выучивает новые представляения данных.

# %% [markdown]
# **Backward pass в MLP**

# %% [markdown]
# Обучается с помощью метода "Error Backpropagation" - ["Обратное распространение ошибки"](https://ru.wikipedia.org/wiki/%D0%9C%D0%B5%D1%82%D0%BE%D0%B4_%D0%BE%D0%B1%D1%80%D0%B0%D1%82%D0%BD%D0%BE%D0%B3%D0%BE_%D1%80%D0%B0%D1%81%D0%BF%D1%80%D0%BE%D1%81%D1%82%D1%80%D0%B0%D0%BD%D0%B5%D0%BD%D0%B8%D1%8F_%D0%BE%D1%88%D0%B8%D0%B1%D0%BA%D0%B8), принцип распространения очень похож на то, как мы обучали один нейрон - это градиентный спуск, но по "всей нейросети" сразу.

# %% [markdown]
# Backpropagation работает корректно благодаря ***chain rule*** (=правилу взятия производной сложной функции):
#
# Если $f(x) = f(g(x))$, то:
#
# $$\frac{\partial{f}}{\partial{x}} = \frac{\partial{f}}{\partial{g}} \frac{\partial{g}}{\partial{x}}$$

# %% [markdown]
# Более подробно про backpropagation можно прочитать здесь (на английском):  https://mattmazur.com/2015/03/17/a-step-by-step-backpropagation-example/

# %% [markdown]
# # Создание двухслойной нейросети
# Cоздадим двухслойную нейросеть из 100 нейронов:

# %%
import matplotlib.pyplot as plt
import numpy as np

import keras

# %% [markdown]
# Генерация датасета:

# %%
N = 100
D = 2
K = 3
X = np.zeros((N * K, D))
y = np.zeros(N * K, dtype='uint8')

for j in range(K):
    ix = range(N * j,N * (j + 1))
    r = np.linspace(0.0, 1, N)
    t = np.linspace(j * 4, (j + 1) * 4,N) + np.random.randn(N) * 0.2 # theta
    X[ix] = np.c_[r * np.sin(t), r * np.cos(t)]
    y[ix] = j

# %%
plt.figure(figsize=(10, 8))
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.rainbow)
plt.title('Спираль', fontsize=15)
plt.xlabel('$x$', fontsize=14)
plt.ylabel('$y$', fontsize=14)
plt.show();

# %%
print(X.data.shape, y.data.shape)
# Out:
# (300, 2) (300,)

# %%
from keras.utils import np_utils
y = keras.utils.np_utils.to_categorical(y, 3)

# %%
from keras import optimizers
two_layer_net=keras.models.Sequential()
two_layer_net.add(keras.layers.Dense(100, input_shape=(X.shape[1],), activation='relu'))
two_layer_net.add(keras.layers.Dense(3, activation='softmax'))
print(two_layer_net.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               300
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 603
# Trainable params: 603
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#визуализация модели
from keras.utils.vis_utils import plot_model
plot_model(two_layer_net, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
from tensorflow.keras import optimizers
sgd = optimizers.SGD(decay=1e-6, momentum=0.9, nesterov=True, learning_rate=0.01)
two_layer_net.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
history=two_layer_net.fit(X, y, epochs=150, batch_size=64, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/150
# 4/4 [==============================] - 2s 75ms/step - loss: 1.0763 - accuracy: 0.3542 - val_loss: 1.1449 - val_accuracy: 0.1667
# Epoch 2/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.0589 - accuracy: 0.4708 - val_loss: 1.2100 - val_accuracy: 0.0000e+00
# Epoch 3/150
# 4/4 [==============================] - 0s 11ms/step - loss: 1.0326 - accuracy: 0.5792 - val_loss: 1.2855 - val_accuracy: 0.0000e+00
# Epoch 4/150
# 4/4 [==============================] - 0s 12ms/step - loss: 1.0063 - accuracy: 0.6042 - val_loss: 1.3670 - val_accuracy: 0.0000e+00
# Epoch 5/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.9828 - accuracy: 0.5875 - val_loss: 1.4487 - val_accuracy: 0.0000e+00
# Epoch 6/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.9612 - accuracy: 0.5917 - val_loss: 1.5243 - val_accuracy: 0.0000e+00
# Epoch 7/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.9404 - accuracy: 0.6083 - val_loss: 1.5894 - val_accuracy: 0.0000e+00
# Epoch 8/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.9240 - accuracy: 0.6250 - val_loss: 1.6503 - val_accuracy: 0.0000e+00
# Epoch 9/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.9085 - accuracy: 0.6417 - val_loss: 1.7037 - val_accuracy: 0.0000e+00
# Epoch 10/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.8958 - accuracy: 0.6208 - val_loss: 1.7533 - val_accuracy: 0.0000e+00
# Epoch 11/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8824 - accuracy: 0.6333 - val_loss: 1.7969 - val_accuracy: 0.0000e+00
# Epoch 12/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.8700 - accuracy: 0.6375 - val_loss: 1.8333 - val_accuracy: 0.0000e+00
# Epoch 13/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8595 - accuracy: 0.6375 - val_loss: 1.8663 - val_accuracy: 0.0000e+00
# Epoch 14/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.8497 - accuracy: 0.6292 - val_loss: 1.8944 - val_accuracy: 0.0000e+00
# Epoch 15/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.8395 - accuracy: 0.6375 - val_loss: 1.9181 - val_accuracy: 0.0000e+00
# Epoch 16/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8307 - accuracy: 0.6375 - val_loss: 1.9376 - val_accuracy: 0.0000e+00
# Epoch 17/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.8223 - accuracy: 0.6375 - val_loss: 1.9526 - val_accuracy: 0.0000e+00
# Epoch 18/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8144 - accuracy: 0.6375 - val_loss: 1.9686 - val_accuracy: 0.0000e+00
# Epoch 19/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.8073 - accuracy: 0.6458 - val_loss: 1.9797 - val_accuracy: 0.0000e+00
# Epoch 20/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8000 - accuracy: 0.6333 - val_loss: 1.9924 - val_accuracy: 0.0000e+00
# Epoch 21/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7934 - accuracy: 0.6375 - val_loss: 2.0031 - val_accuracy: 0.0000e+00
# Epoch 22/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7868 - accuracy: 0.6375 - val_loss: 2.0136 - val_accuracy: 0.0000e+00
# Epoch 23/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7811 - accuracy: 0.6375 - val_loss: 2.0244 - val_accuracy: 0.0000e+00
# Epoch 24/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7755 - accuracy: 0.6375 - val_loss: 2.0341 - val_accuracy: 0.0000e+00
# Epoch 25/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.7704 - accuracy: 0.6417 - val_loss: 2.0482 - val_accuracy: 0.0000e+00
# Epoch 26/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7647 - accuracy: 0.6417 - val_loss: 2.0585 - val_accuracy: 0.0000e+00
# Epoch 27/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.7601 - accuracy: 0.6375 - val_loss: 2.0658 - val_accuracy: 0.0000e+00
# Epoch 28/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7557 - accuracy: 0.6375 - val_loss: 2.0744 - val_accuracy: 0.0000e+00
# Epoch 29/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7512 - accuracy: 0.6375 - val_loss: 2.0836 - val_accuracy: 0.0000e+00
# Epoch 30/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7471 - accuracy: 0.6375 - val_loss: 2.0945 - val_accuracy: 0.0000e+00
# Epoch 31/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7431 - accuracy: 0.6375 - val_loss: 2.1024 - val_accuracy: 0.0000e+00
# Epoch 32/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.7397 - accuracy: 0.6417 - val_loss: 2.1156 - val_accuracy: 0.0000e+00
# Epoch 33/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7363 - accuracy: 0.6375 - val_loss: 2.1251 - val_accuracy: 0.0000e+00
# Epoch 34/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.7325 - accuracy: 0.6375 - val_loss: 2.1371 - val_accuracy: 0.0000e+00
# Epoch 35/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7291 - accuracy: 0.6375 - val_loss: 2.1432 - val_accuracy: 0.0000e+00
# Epoch 36/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.7260 - accuracy: 0.6333 - val_loss: 2.1488 - val_accuracy: 0.0000e+00
# Epoch 37/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7230 - accuracy: 0.6375 - val_loss: 2.1564 - val_accuracy: 0.0000e+00
# Epoch 38/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7205 - accuracy: 0.6375 - val_loss: 2.1631 - val_accuracy: 0.0000e+00
# Epoch 39/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7173 - accuracy: 0.6375 - val_loss: 2.1732 - val_accuracy: 0.0000e+00
# Epoch 40/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7145 - accuracy: 0.6375 - val_loss: 2.1824 - val_accuracy: 0.0000e+00
# Epoch 41/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.7119 - accuracy: 0.6375 - val_loss: 2.1966 - val_accuracy: 0.0000e+00
# Epoch 42/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7094 - accuracy: 0.6375 - val_loss: 2.2109 - val_accuracy: 0.0000e+00
# Epoch 43/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7069 - accuracy: 0.6375 - val_loss: 2.2199 - val_accuracy: 0.0000e+00
# Epoch 44/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7043 - accuracy: 0.6333 - val_loss: 2.2314 - val_accuracy: 0.0000e+00
# Epoch 45/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7020 - accuracy: 0.6333 - val_loss: 2.2424 - val_accuracy: 0.0000e+00
# Epoch 46/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6998 - accuracy: 0.6292 - val_loss: 2.2512 - val_accuracy: 0.0000e+00
# Epoch 47/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6973 - accuracy: 0.6375 - val_loss: 2.2631 - val_accuracy: 0.0000e+00
# Epoch 48/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6952 - accuracy: 0.6333 - val_loss: 2.2769 - val_accuracy: 0.0000e+00
# Epoch 49/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6927 - accuracy: 0.6333 - val_loss: 2.2943 - val_accuracy: 0.0000e+00
# Epoch 50/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6906 - accuracy: 0.6333 - val_loss: 2.3072 - val_accuracy: 0.0000e+00
# Epoch 51/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6886 - accuracy: 0.6208 - val_loss: 2.3205 - val_accuracy: 0.0000e+00
# Epoch 52/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6863 - accuracy: 0.6167 - val_loss: 2.3308 - val_accuracy: 0.0000e+00
# Epoch 53/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6844 - accuracy: 0.6208 - val_loss: 2.3436 - val_accuracy: 0.0000e+00
# Epoch 54/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6821 - accuracy: 0.6208 - val_loss: 2.3652 - val_accuracy: 0.0000e+00
# Epoch 55/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6804 - accuracy: 0.6292 - val_loss: 2.3860 - val_accuracy: 0.0000e+00
# Epoch 56/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6782 - accuracy: 0.6250 - val_loss: 2.3944 - val_accuracy: 0.0000e+00
# Epoch 57/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6761 - accuracy: 0.6208 - val_loss: 2.4067 - val_accuracy: 0.0000e+00
# Epoch 58/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6741 - accuracy: 0.6208 - val_loss: 2.4230 - val_accuracy: 0.0000e+00
# Epoch 59/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6720 - accuracy: 0.6208 - val_loss: 2.4361 - val_accuracy: 0.0000e+00
# Epoch 60/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6700 - accuracy: 0.6208 - val_loss: 2.4491 - val_accuracy: 0.0000e+00
# Epoch 61/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6686 - accuracy: 0.6208 - val_loss: 2.4628 - val_accuracy: 0.0000e+00
# Epoch 62/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6662 - accuracy: 0.6208 - val_loss: 2.4857 - val_accuracy: 0.0000e+00
# Epoch 63/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6643 - accuracy: 0.6208 - val_loss: 2.5026 - val_accuracy: 0.0000e+00
# Epoch 64/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6625 - accuracy: 0.6208 - val_loss: 2.5200 - val_accuracy: 0.0000e+00
# Epoch 65/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6608 - accuracy: 0.6208 - val_loss: 2.5378 - val_accuracy: 0.0000e+00
# Epoch 66/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6583 - accuracy: 0.6208 - val_loss: 2.5552 - val_accuracy: 0.0000e+00
# Epoch 67/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6565 - accuracy: 0.6250 - val_loss: 2.5675 - val_accuracy: 0.0000e+00
# Epoch 68/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6547 - accuracy: 0.6167 - val_loss: 2.5856 - val_accuracy: 0.0000e+00
# Epoch 69/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6526 - accuracy: 0.6292 - val_loss: 2.6021 - val_accuracy: 0.0000e+00
# Epoch 70/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6507 - accuracy: 0.6333 - val_loss: 2.6149 - val_accuracy: 0.0000e+00
# Epoch 71/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6489 - accuracy: 0.6375 - val_loss: 2.6329 - val_accuracy: 0.0000e+00
# Epoch 72/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6467 - accuracy: 0.6375 - val_loss: 2.6416 - val_accuracy: 0.0000e+00
# Epoch 73/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6451 - accuracy: 0.6375 - val_loss: 2.6503 - val_accuracy: 0.0000e+00
# Epoch 74/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6429 - accuracy: 0.6417 - val_loss: 2.6620 - val_accuracy: 0.0000e+00
# Epoch 75/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6408 - accuracy: 0.6417 - val_loss: 2.6763 - val_accuracy: 0.0000e+00
# Epoch 76/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6389 - accuracy: 0.6417 - val_loss: 2.6882 - val_accuracy: 0.0000e+00
# Epoch 77/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6370 - accuracy: 0.6417 - val_loss: 2.7059 - val_accuracy: 0.0000e+00
# Epoch 78/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6353 - accuracy: 0.6417 - val_loss: 2.7195 - val_accuracy: 0.0000e+00
# Epoch 79/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6331 - accuracy: 0.6417 - val_loss: 2.7336 - val_accuracy: 0.0000e+00
# Epoch 80/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6311 - accuracy: 0.6417 - val_loss: 2.7557 - val_accuracy: 0.0000e+00
# Epoch 81/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6292 - accuracy: 0.6417 - val_loss: 2.7726 - val_accuracy: 0.0000e+00
# Epoch 82/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6272 - accuracy: 0.6417 - val_loss: 2.7915 - val_accuracy: 0.0000e+00
# Epoch 83/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6248 - accuracy: 0.6458 - val_loss: 2.8104 - val_accuracy: 0.0000e+00
# Epoch 84/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6229 - accuracy: 0.6458 - val_loss: 2.8286 - val_accuracy: 0.0000e+00
# Epoch 85/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6208 - accuracy: 0.6500 - val_loss: 2.8523 - val_accuracy: 0.0000e+00
# Epoch 86/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6188 - accuracy: 0.6458 - val_loss: 2.8709 - val_accuracy: 0.0000e+00
# Epoch 87/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6169 - accuracy: 0.6500 - val_loss: 2.8907 - val_accuracy: 0.0000e+00
# Epoch 88/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6149 - accuracy: 0.6500 - val_loss: 2.9133 - val_accuracy: 0.0000e+00
# Epoch 89/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6130 - accuracy: 0.6542 - val_loss: 2.9371 - val_accuracy: 0.0000e+00
# Epoch 90/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6108 - accuracy: 0.6542 - val_loss: 2.9580 - val_accuracy: 0.0000e+00
# Epoch 91/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6087 - accuracy: 0.6583 - val_loss: 2.9770 - val_accuracy: 0.0000e+00
# Epoch 92/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6069 - accuracy: 0.6625 - val_loss: 2.9966 - val_accuracy: 0.0000e+00
# Epoch 93/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6045 - accuracy: 0.6583 - val_loss: 3.0161 - val_accuracy: 0.0000e+00
# Epoch 94/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6030 - accuracy: 0.6542 - val_loss: 3.0365 - val_accuracy: 0.0000e+00
# Epoch 95/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6005 - accuracy: 0.6625 - val_loss: 3.0550 - val_accuracy: 0.0000e+00
# Epoch 96/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5989 - accuracy: 0.6625 - val_loss: 3.0792 - val_accuracy: 0.0000e+00
# Epoch 97/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5966 - accuracy: 0.6667 - val_loss: 3.0932 - val_accuracy: 0.0000e+00
# Epoch 98/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5947 - accuracy: 0.6667 - val_loss: 3.1150 - val_accuracy: 0.0000e+00
# Epoch 99/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5925 - accuracy: 0.6667 - val_loss: 3.1317 - val_accuracy: 0.0000e+00
# Epoch 100/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5904 - accuracy: 0.6667 - val_loss: 3.1602 - val_accuracy: 0.0000e+00
# Epoch 101/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5882 - accuracy: 0.6667 - val_loss: 3.1858 - val_accuracy: 0.0000e+00
# Epoch 102/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5862 - accuracy: 0.6667 - val_loss: 3.2020 - val_accuracy: 0.0000e+00
# Epoch 103/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5845 - accuracy: 0.6667 - val_loss: 3.2229 - val_accuracy: 0.0000e+00
# Epoch 104/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5822 - accuracy: 0.6708 - val_loss: 3.2452 - val_accuracy: 0.0000e+00
# Epoch 105/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5800 - accuracy: 0.6708 - val_loss: 3.2765 - val_accuracy: 0.0000e+00
# Epoch 106/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5781 - accuracy: 0.6708 - val_loss: 3.3028 - val_accuracy: 0.0000e+00
# Epoch 107/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5762 - accuracy: 0.6750 - val_loss: 3.3326 - val_accuracy: 0.0000e+00
# Epoch 108/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5740 - accuracy: 0.6708 - val_loss: 3.3514 - val_accuracy: 0.0000e+00
# Epoch 109/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5720 - accuracy: 0.6667 - val_loss: 3.3611 - val_accuracy: 0.0000e+00
# Epoch 110/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5696 - accuracy: 0.6708 - val_loss: 3.3839 - val_accuracy: 0.0000e+00
# Epoch 111/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5677 - accuracy: 0.6708 - val_loss: 3.4054 - val_accuracy: 0.0000e+00
# Epoch 112/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5656 - accuracy: 0.6708 - val_loss: 3.4329 - val_accuracy: 0.0000e+00
# Epoch 113/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5634 - accuracy: 0.6833 - val_loss: 3.4557 - val_accuracy: 0.0000e+00
# Epoch 114/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5620 - accuracy: 0.6708 - val_loss: 3.4936 - val_accuracy: 0.0000e+00
# Epoch 115/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5593 - accuracy: 0.6833 - val_loss: 3.5138 - val_accuracy: 0.0000e+00
# Epoch 116/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5574 - accuracy: 0.6833 - val_loss: 3.5359 - val_accuracy: 0.0000e+00
# Epoch 117/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5553 - accuracy: 0.6833 - val_loss: 3.5591 - val_accuracy: 0.0000e+00
# Epoch 118/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5533 - accuracy: 0.6833 - val_loss: 3.5825 - val_accuracy: 0.0000e+00
# Epoch 119/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5513 - accuracy: 0.6833 - val_loss: 3.6033 - val_accuracy: 0.0000e+00
# Epoch 120/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5493 - accuracy: 0.6833 - val_loss: 3.6291 - val_accuracy: 0.0000e+00
# Epoch 121/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5473 - accuracy: 0.6833 - val_loss: 3.6642 - val_accuracy: 0.0000e+00
# Epoch 122/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5451 - accuracy: 0.6875 - val_loss: 3.6900 - val_accuracy: 0.0000e+00
# Epoch 123/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5431 - accuracy: 0.6917 - val_loss: 3.7214 - val_accuracy: 0.0000e+00
# Epoch 124/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5411 - accuracy: 0.6958 - val_loss: 3.7470 - val_accuracy: 0.0000e+00
# Epoch 125/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5390 - accuracy: 0.7000 - val_loss: 3.7725 - val_accuracy: 0.0000e+00
# Epoch 126/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5372 - accuracy: 0.6958 - val_loss: 3.7978 - val_accuracy: 0.0000e+00
# Epoch 127/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5351 - accuracy: 0.7042 - val_loss: 3.8110 - val_accuracy: 0.0000e+00
# Epoch 128/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5330 - accuracy: 0.7000 - val_loss: 3.8359 - val_accuracy: 0.0000e+00
# Epoch 129/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5312 - accuracy: 0.7083 - val_loss: 3.8629 - val_accuracy: 0.0000e+00
# Epoch 130/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5292 - accuracy: 0.7083 - val_loss: 3.8800 - val_accuracy: 0.0000e+00
# Epoch 131/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5270 - accuracy: 0.7083 - val_loss: 3.9059 - val_accuracy: 0.0000e+00
# Epoch 132/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5250 - accuracy: 0.7083 - val_loss: 3.9328 - val_accuracy: 0.0000e+00
# Epoch 133/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5231 - accuracy: 0.7125 - val_loss: 3.9549 - val_accuracy: 0.0000e+00
# Epoch 134/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5212 - accuracy: 0.7167 - val_loss: 3.9867 - val_accuracy: 0.0000e+00
# Epoch 135/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5191 - accuracy: 0.7125 - val_loss: 4.0140 - val_accuracy: 0.0000e+00
# Epoch 136/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5180 - accuracy: 0.7125 - val_loss: 4.0353 - val_accuracy: 0.0000e+00
# Epoch 137/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5154 - accuracy: 0.7167 - val_loss: 4.0737 - val_accuracy: 0.0000e+00
# Epoch 138/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5133 - accuracy: 0.7125 - val_loss: 4.0975 - val_accuracy: 0.0000e+00
# Epoch 139/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5117 - accuracy: 0.7125 - val_loss: 4.1151 - val_accuracy: 0.0000e+00
# Epoch 140/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5096 - accuracy: 0.7125 - val_loss: 4.1423 - val_accuracy: 0.0000e+00
# Epoch 141/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5075 - accuracy: 0.7125 - val_loss: 4.1788 - val_accuracy: 0.0000e+00
# Epoch 142/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5057 - accuracy: 0.7125 - val_loss: 4.2038 - val_accuracy: 0.0000e+00
# Epoch 143/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5040 - accuracy: 0.7208 - val_loss: 4.2252 - val_accuracy: 0.0000e+00
# Epoch 144/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5018 - accuracy: 0.7167 - val_loss: 4.2559 - val_accuracy: 0.0000e+00
# Epoch 145/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4998 - accuracy: 0.7167 - val_loss: 4.2773 - val_accuracy: 0.0000e+00
# Epoch 146/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4981 - accuracy: 0.7208 - val_loss: 4.2929 - val_accuracy: 0.0000e+00
# Epoch 147/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4960 - accuracy: 0.7292 - val_loss: 4.3036 - val_accuracy: 0.0000e+00
# Epoch 148/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4941 - accuracy: 0.7333 - val_loss: 4.3240 - val_accuracy: 0.0000e+00
# Epoch 149/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4923 - accuracy: 0.7375 - val_loss: 4.3473 - val_accuracy: 0.0000e+00
# Epoch 150/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4904 - accuracy: 0.7375 - val_loss: 4.3788 - val_accuracy: 0.0000e+00

# %%
plt.plot(history.history['accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
#plt.legend(['train','test'])
plt.show()

# %% [markdown]
# # Создание многослойной нейросети
# Усложним архитектуру нейронной сети прямого распрастронения:

# %%
many_layer_net=keras.models.Sequential()
two_layer_net.add(keras.layers.Dense(100, input_shape=(X.shape[1],), activation='relu'))
two_layer_net.add(keras.layers.Dense(100, activation='relu'))

two_layer_net.add(keras.layers.Dense(100, activation='relu'))
two_layer_net.add(keras.layers.Dense(3, activation='softmax'))
sgd = optimizers.SGD(decay=1e-6, momentum=0.9, nesterov=True, learning_rate=0.001)
two_layer_net.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
history=two_layer_net.fit(X, y, epochs=150, batch_size=64, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/150
# 4/4 [==============================] - 1s 82ms/step - loss: 1.1040 - accuracy: 0.1083 - val_loss: 1.1440 - val_accuracy: 0.0000e+00
# Epoch 2/150
# 4/4 [==============================] - 0s 22ms/step - loss: 1.1007 - accuracy: 0.1083 - val_loss: 1.1543 - val_accuracy: 0.0000e+00
# Epoch 3/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0959 - accuracy: 0.1125 - val_loss: 1.1688 - val_accuracy: 0.0000e+00
# Epoch 4/150
# 4/4 [==============================] - 0s 21ms/step - loss: 1.0896 - accuracy: 0.1208 - val_loss: 1.1851 - val_accuracy: 0.0000e+00
# Epoch 5/150
# 4/4 [==============================] - 0s 18ms/step - loss: 1.0830 - accuracy: 0.1375 - val_loss: 1.2028 - val_accuracy: 0.0000e+00
# Epoch 6/150
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0761 - accuracy: 0.2292 - val_loss: 1.2204 - val_accuracy: 0.0000e+00
# Epoch 7/150
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0696 - accuracy: 0.5958 - val_loss: 1.2382 - val_accuracy: 0.0000e+00
# Epoch 8/150
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0633 - accuracy: 0.6917 - val_loss: 1.2559 - val_accuracy: 0.0000e+00
# Epoch 9/150
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0571 - accuracy: 0.7125 - val_loss: 1.2734 - val_accuracy: 0.0000e+00
# Epoch 10/150
# 4/4 [==============================] - 0s 12ms/step - loss: 1.0512 - accuracy: 0.7208 - val_loss: 1.2902 - val_accuracy: 0.0000e+00
# Epoch 11/150
# 4/4 [==============================] - 0s 13ms/step - loss: 1.0453 - accuracy: 0.7375 - val_loss: 1.3064 - val_accuracy: 0.0000e+00
# Epoch 12/150
# 4/4 [==============================] - 0s 13ms/step - loss: 1.0397 - accuracy: 0.7333 - val_loss: 1.3222 - val_accuracy: 0.0000e+00
# Epoch 13/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.0342 - accuracy: 0.7458 - val_loss: 1.3375 - val_accuracy: 0.0000e+00
# Epoch 14/150
# 4/4 [==============================] - 0s 13ms/step - loss: 1.0289 - accuracy: 0.7458 - val_loss: 1.3527 - val_accuracy: 0.0000e+00
# Epoch 15/150
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0239 - accuracy: 0.7500 - val_loss: 1.3677 - val_accuracy: 0.0000e+00
# Epoch 16/150
# 4/4 [==============================] - 0s 13ms/step - loss: 1.0188 - accuracy: 0.7583 - val_loss: 1.3839 - val_accuracy: 0.0000e+00
# Epoch 17/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.0138 - accuracy: 0.7583 - val_loss: 1.3997 - val_accuracy: 0.0000e+00
# Epoch 18/150
# 4/4 [==============================] - 0s 12ms/step - loss: 1.0088 - accuracy: 0.7583 - val_loss: 1.4152 - val_accuracy: 0.0000e+00
# Epoch 19/150
# 4/4 [==============================] - 0s 13ms/step - loss: 1.0041 - accuracy: 0.7583 - val_loss: 1.4308 - val_accuracy: 0.0000e+00
# Epoch 20/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.9994 - accuracy: 0.7583 - val_loss: 1.4459 - val_accuracy: 0.0000e+00
# Epoch 21/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.9949 - accuracy: 0.7583 - val_loss: 1.4610 - val_accuracy: 0.0000e+00
# Epoch 22/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.9903 - accuracy: 0.7583 - val_loss: 1.4754 - val_accuracy: 0.0000e+00
# Epoch 23/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.9858 - accuracy: 0.7583 - val_loss: 1.4901 - val_accuracy: 0.0000e+00
# Epoch 24/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.9815 - accuracy: 0.7625 - val_loss: 1.5042 - val_accuracy: 0.0000e+00
# Epoch 25/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.9769 - accuracy: 0.7625 - val_loss: 1.5173 - val_accuracy: 0.0000e+00
# Epoch 26/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.9726 - accuracy: 0.7583 - val_loss: 1.5304 - val_accuracy: 0.0000e+00
# Epoch 27/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.9685 - accuracy: 0.7583 - val_loss: 1.5447 - val_accuracy: 0.0000e+00
# Epoch 28/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.9644 - accuracy: 0.7583 - val_loss: 1.5581 - val_accuracy: 0.0000e+00
# Epoch 29/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.9599 - accuracy: 0.7583 - val_loss: 1.5708 - val_accuracy: 0.0000e+00
# Epoch 30/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.9558 - accuracy: 0.7583 - val_loss: 1.5839 - val_accuracy: 0.0000e+00
# Epoch 31/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.9517 - accuracy: 0.7583 - val_loss: 1.5971 - val_accuracy: 0.0000e+00
# Epoch 32/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.9474 - accuracy: 0.7583 - val_loss: 1.6095 - val_accuracy: 0.0000e+00
# Epoch 33/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.9432 - accuracy: 0.7583 - val_loss: 1.6217 - val_accuracy: 0.0000e+00
# Epoch 34/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.9390 - accuracy: 0.7583 - val_loss: 1.6347 - val_accuracy: 0.0000e+00
# Epoch 35/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.9349 - accuracy: 0.7583 - val_loss: 1.6474 - val_accuracy: 0.0000e+00
# Epoch 36/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.9308 - accuracy: 0.7583 - val_loss: 1.6605 - val_accuracy: 0.0000e+00
# Epoch 37/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.9266 - accuracy: 0.7583 - val_loss: 1.6730 - val_accuracy: 0.0000e+00
# Epoch 38/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.9222 - accuracy: 0.7583 - val_loss: 1.6843 - val_accuracy: 0.0000e+00
# Epoch 39/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.9180 - accuracy: 0.7583 - val_loss: 1.6958 - val_accuracy: 0.0000e+00
# Epoch 40/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.9136 - accuracy: 0.7542 - val_loss: 1.7069 - val_accuracy: 0.0000e+00
# Epoch 41/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.9093 - accuracy: 0.7542 - val_loss: 1.7184 - val_accuracy: 0.0000e+00
# Epoch 42/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.9049 - accuracy: 0.7542 - val_loss: 1.7298 - val_accuracy: 0.0000e+00
# Epoch 43/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.9005 - accuracy: 0.7583 - val_loss: 1.7410 - val_accuracy: 0.0000e+00
# Epoch 44/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.8960 - accuracy: 0.7583 - val_loss: 1.7523 - val_accuracy: 0.0000e+00
# Epoch 45/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8917 - accuracy: 0.7583 - val_loss: 1.7643 - val_accuracy: 0.0000e+00
# Epoch 46/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8870 - accuracy: 0.7583 - val_loss: 1.7752 - val_accuracy: 0.0000e+00
# Epoch 47/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8825 - accuracy: 0.7583 - val_loss: 1.7864 - val_accuracy: 0.0000e+00
# Epoch 48/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8777 - accuracy: 0.7583 - val_loss: 1.7963 - val_accuracy: 0.0000e+00
# Epoch 49/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8731 - accuracy: 0.7583 - val_loss: 1.8071 - val_accuracy: 0.0000e+00
# Epoch 50/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.8681 - accuracy: 0.7583 - val_loss: 1.8167 - val_accuracy: 0.0000e+00
# Epoch 51/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.8633 - accuracy: 0.7583 - val_loss: 1.8273 - val_accuracy: 0.0000e+00
# Epoch 52/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8583 - accuracy: 0.7583 - val_loss: 1.8372 - val_accuracy: 0.0000e+00
# Epoch 53/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.8533 - accuracy: 0.7583 - val_loss: 1.8480 - val_accuracy: 0.0000e+00
# Epoch 54/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.8483 - accuracy: 0.7583 - val_loss: 1.8591 - val_accuracy: 0.0000e+00
# Epoch 55/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8432 - accuracy: 0.7583 - val_loss: 1.8698 - val_accuracy: 0.0000e+00
# Epoch 56/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.8381 - accuracy: 0.7583 - val_loss: 1.8798 - val_accuracy: 0.0000e+00
# Epoch 57/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8331 - accuracy: 0.7583 - val_loss: 1.8908 - val_accuracy: 0.0000e+00
# Epoch 58/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8280 - accuracy: 0.7583 - val_loss: 1.9023 - val_accuracy: 0.0000e+00
# Epoch 59/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.8229 - accuracy: 0.7583 - val_loss: 1.9142 - val_accuracy: 0.0000e+00
# Epoch 60/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.8179 - accuracy: 0.7583 - val_loss: 1.9262 - val_accuracy: 0.0000e+00
# Epoch 61/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.8126 - accuracy: 0.7583 - val_loss: 1.9369 - val_accuracy: 0.0000e+00
# Epoch 62/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.8076 - accuracy: 0.7583 - val_loss: 1.9485 - val_accuracy: 0.0000e+00
# Epoch 63/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.8025 - accuracy: 0.7583 - val_loss: 1.9619 - val_accuracy: 0.0000e+00
# Epoch 64/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.7972 - accuracy: 0.7583 - val_loss: 1.9738 - val_accuracy: 0.0000e+00
# Epoch 65/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.7919 - accuracy: 0.7583 - val_loss: 1.9860 - val_accuracy: 0.0000e+00
# Epoch 66/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.7867 - accuracy: 0.7583 - val_loss: 1.9986 - val_accuracy: 0.0000e+00
# Epoch 67/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.7815 - accuracy: 0.7583 - val_loss: 2.0111 - val_accuracy: 0.0000e+00
# Epoch 68/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7762 - accuracy: 0.7583 - val_loss: 2.0244 - val_accuracy: 0.0000e+00
# Epoch 69/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7709 - accuracy: 0.7583 - val_loss: 2.0370 - val_accuracy: 0.0000e+00
# Epoch 70/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.7657 - accuracy: 0.7583 - val_loss: 2.0504 - val_accuracy: 0.0000e+00
# Epoch 71/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7606 - accuracy: 0.7583 - val_loss: 2.0640 - val_accuracy: 0.0000e+00
# Epoch 72/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.7552 - accuracy: 0.7583 - val_loss: 2.0779 - val_accuracy: 0.0000e+00
# Epoch 73/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7501 - accuracy: 0.7583 - val_loss: 2.0915 - val_accuracy: 0.0000e+00
# Epoch 74/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.7447 - accuracy: 0.7583 - val_loss: 2.1048 - val_accuracy: 0.0000e+00
# Epoch 75/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7396 - accuracy: 0.7583 - val_loss: 2.1170 - val_accuracy: 0.0000e+00
# Epoch 76/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.7344 - accuracy: 0.7583 - val_loss: 2.1309 - val_accuracy: 0.0000e+00
# Epoch 77/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7294 - accuracy: 0.7583 - val_loss: 2.1463 - val_accuracy: 0.0000e+00
# Epoch 78/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.7242 - accuracy: 0.7583 - val_loss: 2.1608 - val_accuracy: 0.0000e+00
# Epoch 79/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7192 - accuracy: 0.7583 - val_loss: 2.1747 - val_accuracy: 0.0000e+00
# Epoch 80/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.7140 - accuracy: 0.7583 - val_loss: 2.1889 - val_accuracy: 0.0000e+00
# Epoch 81/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7091 - accuracy: 0.7583 - val_loss: 2.2032 - val_accuracy: 0.0000e+00
# Epoch 82/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.7040 - accuracy: 0.7625 - val_loss: 2.2185 - val_accuracy: 0.0000e+00
# Epoch 83/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6990 - accuracy: 0.7625 - val_loss: 2.2335 - val_accuracy: 0.0000e+00
# Epoch 84/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6941 - accuracy: 0.7625 - val_loss: 2.2483 - val_accuracy: 0.0000e+00
# Epoch 85/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6893 - accuracy: 0.7625 - val_loss: 2.2634 - val_accuracy: 0.0000e+00
# Epoch 86/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6845 - accuracy: 0.7625 - val_loss: 2.2798 - val_accuracy: 0.0000e+00
# Epoch 87/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6797 - accuracy: 0.7625 - val_loss: 2.2949 - val_accuracy: 0.0000e+00
# Epoch 88/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6752 - accuracy: 0.7625 - val_loss: 2.3107 - val_accuracy: 0.0000e+00
# Epoch 89/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6705 - accuracy: 0.7625 - val_loss: 2.3262 - val_accuracy: 0.0000e+00
# Epoch 90/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6659 - accuracy: 0.7625 - val_loss: 2.3417 - val_accuracy: 0.0000e+00
# Epoch 91/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6614 - accuracy: 0.7625 - val_loss: 2.3582 - val_accuracy: 0.0000e+00
# Epoch 92/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6571 - accuracy: 0.7625 - val_loss: 2.3746 - val_accuracy: 0.0000e+00
# Epoch 93/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6527 - accuracy: 0.7625 - val_loss: 2.3891 - val_accuracy: 0.0000e+00
# Epoch 94/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6484 - accuracy: 0.7625 - val_loss: 2.4039 - val_accuracy: 0.0000e+00
# Epoch 95/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6441 - accuracy: 0.7625 - val_loss: 2.4201 - val_accuracy: 0.0000e+00
# Epoch 96/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6400 - accuracy: 0.7625 - val_loss: 2.4356 - val_accuracy: 0.0000e+00
# Epoch 97/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6361 - accuracy: 0.7625 - val_loss: 2.4521 - val_accuracy: 0.0000e+00
# Epoch 98/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6319 - accuracy: 0.7625 - val_loss: 2.4688 - val_accuracy: 0.0000e+00
# Epoch 99/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6280 - accuracy: 0.7625 - val_loss: 2.4857 - val_accuracy: 0.0000e+00
# Epoch 100/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6242 - accuracy: 0.7625 - val_loss: 2.5036 - val_accuracy: 0.0000e+00
# Epoch 101/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6203 - accuracy: 0.7625 - val_loss: 2.5204 - val_accuracy: 0.0000e+00
# Epoch 102/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6165 - accuracy: 0.7625 - val_loss: 2.5367 - val_accuracy: 0.0000e+00
# Epoch 103/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6129 - accuracy: 0.7625 - val_loss: 2.5538 - val_accuracy: 0.0000e+00
# Epoch 104/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6093 - accuracy: 0.7625 - val_loss: 2.5690 - val_accuracy: 0.0000e+00
# Epoch 105/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6059 - accuracy: 0.7625 - val_loss: 2.5837 - val_accuracy: 0.0000e+00
# Epoch 106/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6024 - accuracy: 0.7625 - val_loss: 2.5995 - val_accuracy: 0.0000e+00
# Epoch 107/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5989 - accuracy: 0.7625 - val_loss: 2.6177 - val_accuracy: 0.0000e+00
# Epoch 108/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5956 - accuracy: 0.7625 - val_loss: 2.6363 - val_accuracy: 0.0000e+00
# Epoch 109/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5924 - accuracy: 0.7625 - val_loss: 2.6546 - val_accuracy: 0.0000e+00
# Epoch 110/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5893 - accuracy: 0.7625 - val_loss: 2.6715 - val_accuracy: 0.0000e+00
# Epoch 111/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5861 - accuracy: 0.7625 - val_loss: 2.6891 - val_accuracy: 0.0000e+00
# Epoch 112/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5830 - accuracy: 0.7625 - val_loss: 2.7072 - val_accuracy: 0.0000e+00
# Epoch 113/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5802 - accuracy: 0.7625 - val_loss: 2.7238 - val_accuracy: 0.0000e+00
# Epoch 114/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5772 - accuracy: 0.7625 - val_loss: 2.7419 - val_accuracy: 0.0000e+00
# Epoch 115/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5744 - accuracy: 0.7625 - val_loss: 2.7612 - val_accuracy: 0.0000e+00
# Epoch 116/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5715 - accuracy: 0.7625 - val_loss: 2.7786 - val_accuracy: 0.0000e+00
# Epoch 117/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5688 - accuracy: 0.7625 - val_loss: 2.7951 - val_accuracy: 0.0000e+00
# Epoch 118/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5661 - accuracy: 0.7625 - val_loss: 2.8122 - val_accuracy: 0.0000e+00
# Epoch 119/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5634 - accuracy: 0.7625 - val_loss: 2.8313 - val_accuracy: 0.0000e+00
# Epoch 120/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5608 - accuracy: 0.7625 - val_loss: 2.8504 - val_accuracy: 0.0000e+00
# Epoch 121/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5583 - accuracy: 0.7625 - val_loss: 2.8663 - val_accuracy: 0.0000e+00
# Epoch 122/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5558 - accuracy: 0.7625 - val_loss: 2.8813 - val_accuracy: 0.0000e+00
# Epoch 123/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5533 - accuracy: 0.7625 - val_loss: 2.8954 - val_accuracy: 0.0000e+00
# Epoch 124/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5509 - accuracy: 0.7625 - val_loss: 2.9140 - val_accuracy: 0.0000e+00
# Epoch 125/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5484 - accuracy: 0.7625 - val_loss: 2.9322 - val_accuracy: 0.0000e+00
# Epoch 126/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5460 - accuracy: 0.7625 - val_loss: 2.9490 - val_accuracy: 0.0000e+00
# Epoch 127/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5438 - accuracy: 0.7625 - val_loss: 2.9667 - val_accuracy: 0.0000e+00
# Epoch 128/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5415 - accuracy: 0.7625 - val_loss: 2.9852 - val_accuracy: 0.0000e+00
# Epoch 129/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5393 - accuracy: 0.7625 - val_loss: 3.0032 - val_accuracy: 0.0000e+00
# Epoch 130/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5371 - accuracy: 0.7625 - val_loss: 3.0183 - val_accuracy: 0.0000e+00
# Epoch 131/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5350 - accuracy: 0.7625 - val_loss: 3.0343 - val_accuracy: 0.0000e+00
# Epoch 132/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5329 - accuracy: 0.7625 - val_loss: 3.0510 - val_accuracy: 0.0000e+00
# Epoch 133/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5308 - accuracy: 0.7625 - val_loss: 3.0661 - val_accuracy: 0.0000e+00
# Epoch 134/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5287 - accuracy: 0.7625 - val_loss: 3.0832 - val_accuracy: 0.0000e+00
# Epoch 135/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5269 - accuracy: 0.7625 - val_loss: 3.1011 - val_accuracy: 0.0000e+00
# Epoch 136/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5249 - accuracy: 0.7625 - val_loss: 3.1197 - val_accuracy: 0.0000e+00
# Epoch 137/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5230 - accuracy: 0.7667 - val_loss: 3.1373 - val_accuracy: 0.0000e+00
# Epoch 138/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5211 - accuracy: 0.7667 - val_loss: 3.1559 - val_accuracy: 0.0000e+00
# Epoch 139/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5193 - accuracy: 0.7667 - val_loss: 3.1752 - val_accuracy: 0.0000e+00
# Epoch 140/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5175 - accuracy: 0.7625 - val_loss: 3.1933 - val_accuracy: 0.0000e+00
# Epoch 141/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5157 - accuracy: 0.7667 - val_loss: 3.2115 - val_accuracy: 0.0000e+00
# Epoch 142/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5140 - accuracy: 0.7667 - val_loss: 3.2293 - val_accuracy: 0.0000e+00
# Epoch 143/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5124 - accuracy: 0.7667 - val_loss: 3.2467 - val_accuracy: 0.0000e+00
# Epoch 144/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5107 - accuracy: 0.7667 - val_loss: 3.2621 - val_accuracy: 0.0000e+00
# Epoch 145/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5091 - accuracy: 0.7667 - val_loss: 3.2804 - val_accuracy: 0.0000e+00
# Epoch 146/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5074 - accuracy: 0.7667 - val_loss: 3.2965 - val_accuracy: 0.0000e+00
# Epoch 147/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5059 - accuracy: 0.7667 - val_loss: 3.3144 - val_accuracy: 0.0000e+00
# Epoch 148/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5042 - accuracy: 0.7667 - val_loss: 3.3322 - val_accuracy: 0.0000e+00
# Epoch 149/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5028 - accuracy: 0.7667 - val_loss: 3.3517 - val_accuracy: 0.0000e+00
# Epoch 150/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5012 - accuracy: 0.7667 - val_loss: 3.3705 - val_accuracy: 0.0000e+00

# %%
plt.plot(history.history['accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %% [markdown]
# # Задание 1
# 1. Попробовать улучшить результат за счет изменения следующих параметров: скорость обучения, количество эпох, виды оптимизаторов, количество нейронов, количество слоев. Результаты анализа представить в виде графиков (диаграмм)
# 2. Добавить слой (слои) Dropout (model.add(keras.layers.Dropout(0.5))), посмотреть как измениться результат
# 3. Добавить слой нормализации (keras.layers.BatchNormalization) и оценить его влияние на качество обучения.

# %% [markdown]
# # Создание многослойной нейросети для классификации рукописных цифр

# %%
import keras

from keras.datasets import mnist
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.models import Sequential
from keras.optimizers import adam_v2
from keras.utils import np_utils
from keras.utils import np_utils

import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

number_of_classes = 10

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

plt.figure()
plt.imshow(X_train[0])
plt.colorbar()
plt.grid(False)

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i], cmap=plt.cm.binary)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1]*X_train.shape[2]).astype('float32')
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1]*X_test.shape[2]).astype('float32')

#для преобразования двумерных данных в одномерные в нейронной сети можно использовать слой Flatten(input_shape=(28,28))

X_train/=255
X_test/=255

y_train = np_utils.to_categorical(y_train, number_of_classes)
y_test = np_utils.to_categorical(y_test, number_of_classes)

# %%
X_train.shape
# Out:
# (60000, 784)

# %%
model = keras.models.Sequential()
model.add(keras.layers.Dense(512, input_dim=(X_train.shape[1]), activation='relu'))
model.add(keras.layers.Dense(number_of_classes, activation='softmax'))
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 512)               401920
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history=model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5, batch_size=200)
# Out:
# Epoch 1/5
# 300/300 [==============================] - 3s 8ms/step - loss: 0.3046 - accuracy: 0.9153 - val_loss: 0.1558 - val_accuracy: 0.9543
# Epoch 2/5
# 300/300 [==============================] - 2s 5ms/step - loss: 0.1257 - accuracy: 0.9640 - val_loss: 0.1052 - val_accuracy: 0.9684
# Epoch 3/5
# 300/300 [==============================] - 2s 5ms/step - loss: 0.0832 - accuracy: 0.9764 - val_loss: 0.0862 - val_accuracy: 0.9746
# Epoch 4/5
# 300/300 [==============================] - 2s 8ms/step - loss: 0.0600 - accuracy: 0.9828 - val_loss: 0.0841 - val_accuracy: 0.9731
# Epoch 5/5
# 300/300 [==============================] - 1s 4ms/step - loss: 0.0459 - accuracy: 0.9872 - val_loss: 0.0737 - val_accuracy: 0.9776

# %%
#оценка точности
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
print('Test loss:', test_loss)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0737 - accuracy: 0.9776
# Test accuracy: 0.9775999784469604
# Test loss: 0.07374592870473862

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax1.plot(history.history['accuracy'])
ax1.plot(history.history['val_accuracy'])
ax1.set(title='model accuracy')
ax1.set(ylabel='accuracy')
ax1.set(xlabel='epoch')
ax1.legend(['train', 'test'], loc='upper left')
ax2 = fig.add_subplot(1,2,2)
ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set(title='model loss')
ax2.set(ylabel='loss')
ax2.set(xlabel='epoch')
ax2.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Задание 2
# 1. Между двух слоев нейронной сети добавить слой Dropout
# model.add(keras.layers.Dropout(0.5)), переобучить модель, оценить качество обучения.
# Объяснить полученные результаты
# 2. Добавить еще один скрытый слой и проанализировать его влияние на качество обучения модели.

# %% [markdown]
# # Инициализация сети
# Важным моментом при конструировании сети является начальная инициализация весов. Удачно выбранный способ инициализации весов может значительно влиять на способность модели к обучению.
#
# Существует различные подходы к начальной инициализации весов.
#
# Например, метод Завьера. Основная идея этого метода — упростить прохождение сигнала через слой во время как прямого, так и обратного распространения ошибки для линейной функции активации (этот метод также хорошо работает для сигмоидной функции, так как участок, где она ненасыщена, также имеет линейный характер). При вычислении весов этот метод опирается на вероятностное распределение.
#
# Метод инициализации Ге (He) — это вариация метода Завьера, больше подходящая функции активации ReLU, компенсирующая тот факт, что эта функция возвращает нуль для половины области определения.
#
# Выделяют также метод ортогональной инициализации.

# %%
model_reg = keras.models.Sequential()
model_reg.add(keras.layers.Dense(512, input_dim=(X_train.shape[1]), activation='relu', kernel_initializer='he_uniform'))
model_reg.add(keras.layers.Dense(number_of_classes, activation='softmax', kernel_initializer='glorot_uniform'))

# %% [markdown]
# # L2-регуляризация
# Одной из основных проблем машинного обучения является проблема переобучения (overfitting), когда модель в погоне за минимизацией затрат на обучение теряет способность к обобщению.
#
# Существует простой способ держать переобучение под контролем — метод dropout.
#
# Но есть и другие регуляризаторы, которые можно применить к сети. Один из них — L_2-регуляризация (также называемая сокращением весов, англ. weight decay), которая использует более прямой подход к регуляризации, чем dropout. Обычно первопричиной переобучения является сложность модели (в смысле количества ее параметров), слишком высокая для решаемой задачи и имеющегося обучающего множества. В некотором смысле, задача регуляризатора — понизить сложность модели, сохранив количество ее параметров.
#
# L_2-регуляризация выполняется посредством наложения штрафов (penalising) на веса с наибольшими значениями, минимизируя их L_2-норму с использованием параметра λ — коэффициент регуляризации, выражающий предпочтение минимизации нормы относительно минимизации потерь на обучающем множестве.
#
# Крайне важно правильно выбрать λ. Если коэффициент слишком мал, то эффект от регуляризации будет ничтожен, если же слишком велик — модель обнулит все веса.

# %%
from keras.regularizers import l2
l2_lambda = 0.0001
model_reg = keras.models.Sequential()
model_reg.add(keras.layers.Dense(512, input_dim=(X_train.shape[1]), activation='relu',kernel_initializer='he_uniform', bias_regularizer=l2(l2_lambda)))
model_reg.add(keras.layers.Dense(number_of_classes, activation='softmax', kernel_initializer='glorot_uniform'))

# %%
model_reg.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history=model_reg.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5, batch_size=200)
# Out:
# Epoch 1/5
# 300/300 [==============================] - 2s 5ms/step - loss: 0.3011 - accuracy: 0.9140 - val_loss: 0.1499 - val_accuracy: 0.9582
# Epoch 2/5
# 300/300 [==============================] - 1s 4ms/step - loss: 0.1228 - accuracy: 0.9651 - val_loss: 0.1044 - val_accuracy: 0.9692
# Epoch 3/5
# 300/300 [==============================] - 1s 4ms/step - loss: 0.0811 - accuracy: 0.9765 - val_loss: 0.0831 - val_accuracy: 0.9755
# Epoch 4/5
# 300/300 [==============================] - 2s 5ms/step - loss: 0.0590 - accuracy: 0.9831 - val_loss: 0.0795 - val_accuracy: 0.9755
# Epoch 5/5
# 300/300 [==============================] - 1s 4ms/step - loss: 0.0439 - accuracy: 0.9872 - val_loss: 0.0708 - val_accuracy: 0.9783

# %% [markdown]
# ## Задание 3
# Измените коэффициент регуляризации на значение 0.5; 0.01 и 1, оцените влияние значения коэффициента на точность сети
#
# Попробуйте использовать схему регуляризации L1 (bias_regularizer=tf.keras.regularizers.l1(0.0001)), сравните точности модели при L1 и L2 регуляризации.

# %% [markdown]
# ## Применение обученной нейронной сети
# Необходимо нарисовать цифру (например в Paint) или скачать из Интернета

# %%
#выполняем преобразование картинки с цифрой
from PIL import Image
#преобразование входного изображения в формат набора MNIS
image=Image.open("cifra-2.png").resize((28,28))
img = np.invert(image.convert('L')).ravel()
im2arr = img.reshape(1, 28* 28).astype('float32')/255
#plt.imshow(image, cmap=plt.cm.binary)
#использование обученной модели
y_pred = model.predict(im2arr)
print(y_pred[0]) 
plt.bar(range(10), y_pred[0])
plt.show()
print(np.argmax(y_pred))
# Out:
# [1.4453518e-11 1.0677580e-11 6.7775865e-04 4.6621627e-01 3.0039981e-24
#  3.2977484e-02 8.3165309e-05 5.0001395e-01 3.1352767e-05 6.3720331e-12]
# 7

# %%
#сохранение модели
model.save('model.h5') 

#загрузка модели
#model_load=keras.models.load_model('model.h5')

# %% [markdown]
# ## Задание 4
# Описать архитектуру многослойной нейронной сети для классификации вина (использовать датасет из scikit learn), обучить ее, проверить качество обучения, использовать для предсказания и сохранить

# %% [markdown]
# # Задание 5
# Решить задачу классификации или регрессии для датасета, найденного в 1 практической работе
